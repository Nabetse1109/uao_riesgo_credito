# %% [markdown]
# <a href="https://colab.research.google.com/github/Nabetse1109/uao_riesgo_credito/blob/main/notebooks/01_data_understanding.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Proyecto: Gestión del riesgo y cobranza mediante modelos predictivos en créditos educativos**
#
# Autores: Paula Andrea Tovar Ríos, Edgar Esteban Grajales Castaño
#
# Entorno: Google Colab - Python

# %% [markdown]
# Importación de librerías:

# %%
# Importación de librerías

import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

# Configuración gráfica
plt.rcParams["figure.figsize"] = (10, 5)
sns.set(style="whitegrid", font_scale=1.0)

# Para que se vean todas las columnas cuando inspeccionemos dataframes
pd.set_option("display.max_columns", None)
pd.set_option("display.width", 120)

# %% [markdown]
# Ruta:

# %%
# Conexión a Google Drive y carga de datasets

from google.colab import drive
import pandas as pd

# Montar Google Drive
drive.mount('/content/drive')

# Ruta base del proyecto en tu Drive
BASE_DIR = "/content/drive/MyDrive/uao_riesgo_credito"

# Subcarpetas
DATA_RAW_DIR = f"{BASE_DIR}/data/raw"
DATA_PROCESSED_DIR = f"{BASE_DIR}/data/processed"

# Paths completos de los datasets
CREDITOS_PATH = f"{DATA_RAW_DIR}/1_Creditos_Estudiantes.xlsx"
CARTERA_PATH = f"{DATA_RAW_DIR}/2_Cartera_depurada.xlsx"
PAGARES_PATH = f"{DATA_RAW_DIR}/3_Info_Pagares.xlsx"

CREDITOS_PATH, CARTERA_PATH, PAGARES_PATH
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# ('/content/drive/MyDrive/uao_riesgo_credito/data/raw/1_Creditos_Estudiantes.xlsx',
#  '/content/drive/MyDrive/uao_riesgo_credito/data/raw/2_Cartera_depurada.xlsx',
#  '/content/drive/MyDrive/uao_riesgo_credito/data/raw/3_Info_Pagares.xlsx')

# %% [markdown]
# Carga de datasets:

# %%
# Cargar los datasets en dataframes

print("Cargando datasets...")

creditos_df = pd.read_excel(CREDITOS_PATH)
cartera_df  = pd.read_excel(CARTERA_PATH)
pagares_df  = pd.read_excel(PAGARES_PATH)

print("Datasets cargados correctamente:")
print(f" - Créditos: {creditos_df.shape}")
print(f" - Cartera depurada: {cartera_df.shape}")
print(f" - Info Pagares: {pagares_df.shape}")
# Out:
# Cargando datasets...
# Datasets cargados correctamente:
#  - Créditos: (405829, 30)
#  - Cartera depurada: (27330, 66)
#  - Info Pagares: (522286, 10)

# %% [markdown]
# Estilo de las tablas:

# %%
# Función para dar estilo a las tablas

def estilo_tabla(df, titulo=None):
    """
    Aplica estilo a un DataFrame para visualización en Colab / Jupyter.
    - Encabezados oscuros
    - Bordes sutiles
    - Nulos resaltados
    - Título tipo caption
    """
    # Copia para evitar modificar el original
    df_to_style = df.copy()

    # Arrancamos el styler
    styled = df_to_style.style

    # Caption (título)
    if titulo:
        styled = styled.set_caption(titulo)

    # Estilos de la tabla
    styled = styled.set_table_styles([
        {
            "selector": "caption",
            "props": [
                ("color", "#2c3e50"),
                ("font-size", "16px"),
                ("font-weight", "bold"),
                ("text-align", "left"),
                ("margin-bottom", "10px")
            ]
        },
        {
            "selector": "th",
            "props": [
                ("background-color", "#2c3e50"),
                ("color", "white"),
                ("font-weight", "bold"),
                ("border", "1px solid #ddd"),
                ("padding", "5px")
            ]
        },
        {
            "selector": "td",
            "props": [
                ("border", "1px solid #ddd"),
                ("padding", "5px")
            ]
        }
    ])

    # Alineación
    styled = styled.set_properties(**{"text-align": "left"})

    # Resaltar nulos
    styled = styled.highlight_null(color="#f8d7da")

    # Formatear columnas numéricas (separador de miles)
    numeric_cols = df_to_style.select_dtypes(include="number").columns
    if len(numeric_cols) > 0:
        fmt_dict = {col: "{:,.0f}".format for col in numeric_cols}
        styled = styled.format(fmt_dict, na_rep="-")

    return styled

# %% [markdown]
# Vista rápida primeras filas:

# %%
# Primer vistazo a los datos (head)

# Créditos
estilo_tabla(creditos_df.head(), titulo="Primeras filas del dataset de Créditos")
# Out:
# <style type="text/css">
# #T_02e2a caption {
#   color: #2c3e50;
#   font-size: 16px;
#   font-weight: bold;
#   text-align: left;
#   margin-bottom: 10px;
# }
# #T_02e2a th {
#   background-color: #2c3e50;
#   color: white;
#   font-weight: bold;
#   border: 1px solid #ddd;
#   padding: 5px;
# }
# #T_02e2a td {
#   border: 1px solid #ddd;
#   padding: 5px;
# }
# #T_02e2a_row0_col0, #T_02e2a_row0_col1, #T_02e2a_row0_col2, #T_02e2a_row0_col3, #T_02e2a_row0_col4, #T_02e2a_row0_col5, #T_02e2a_row0_col6, #T_02e2a_row0_col7, #T_02e2a_row0_col8, #T_02e2a_row0_col9, #T_02e2a_row0_col10, #T_02e2a_row0_col11, #T_02e2a_row0_col12, #T_02e2a_row0_col13, #T_02e2a_row0_col14, #T_02e2a_row0_col15, #T_02e2a_row0_col16, #T_02e2a_row0_col17, #T_02e2a_row0_col20, #T_02e2a_row0_col21, #T_02e2a_row0_col22, #T_02e2a_row0_col23, #T_02e2a_row0_col24, #T_02e2a_row0_col25, #T_02e2a_row0_col26, #T_02e2a_row0_col27, #T_02e2a_row0_col28, #T_02e2a_row0_col29, #T_02e2a_row1_col0, #T_02e2a_row1_col1, #T_02e2a_row1_col2, #T_02e2a_row1_col3, #T_02e2a_row1_col4, #T_02e2a_row1_col5, #T_02e2a_row1_col6, #T_02e2a_row1_col7, #T_02e2a_row1_col8, #T_02e2a_row1_col9, #T_02e2a_row1_col10, #T_02e2a_row1_col11, #T_02e2a_row1_col12, #T_02e2a_row1_col13, #T_02e2a_row1_col14, #T_02e2a_row1_col15, #T_02e2a_row1_col16, #T_02e2a_row1_col17, #T_02e2a_row1_col20, #T_02e2a_row1_col21, #T_02e2a_row1_col22, #T_02e2a_row1_col23, #T_02e2a_row1_col24, #T_02e2a_row1_col25, #T_02e2a_row1_col26, #T_02e2a_row1_col27, #T_02e2a_row1_col28, #T_02e2a_row1_col29, #T_02e2a_row2_col0, #T_02e2a_row2_col1, #T_02e2a_row2_col2, #T_02e2a_row2_col3, #T_02e2a_row2_col4, #T_02e2a_row2_col5, #T_02e2a_row2_col6, #T_02e2a_row2_col7, #T_02e2a_row2_col8, #T_02e2a_row2_col9, #T_02e2a_row2_col10, #T_02e2a_row2_col11, #T_02e2a_row2_col12, #T_02e2a_row2_col13, #T_02e2a_row2_col14, #T_02e2a_row2_col15, #T_02e2a_row2_col16, #T_02e2a_row2_col17, #T_02e2a_row2_col20, #T_02e2a_row2_col21, #T_02e2a_row2_col22, #T_02e2a_row2_col23, #T_02e2a_row2_col24, #T_02e2a_row2_col25, #T_02e2a_row2_col26, #T_02e2a_row2_col27, #T_02e2a_row2_col28, #T_02e2a_row2_col29, #T_02e2a_row3_col0, #T_02e2a_row3_col1, #T_02e2a_row3_col2, #T_02e2a_row3_col3, #T_02e2a_row3_col4, #T_02e2a_row3_col5, #T_02e2a_row3_col6, #T_02e2a_row3_col7, #T_02e2a_row3_col8, #T_02e2a_row3_col9, #T_02e2a_row3_col10, #T_02e2a_row3_col11, #T_02e2a_row3_col12, #T_02e2a_row3_col13, #T_02e2a_row3_col14, #T_02e2a_row3_col15, #T_02e2a_row3_col16, #T_02e2a_row3_col17, #T_02e2a_row3_col20, #T_02e2a_row3_col21, #T_02e2a_row3_col22, #T_02e2a_row3_col23, #T_02e2a_row3_col24, #T_02e2a_row3_col25, #T_02e2a_row3_col26, #T_02e2a_row3_col27, #T_02e2a_row3_col28, #T_02e2a_row3_col29, #T_02e2a_row4_col0, #T_02e2a_row4_col1, #T_02e2a_row4_col2, #T_02e2a_row4_col3, #T_02e2a_row4_col4, #T_02e2a_row4_col5, #T_02e2a_row4_col6, #T_02e2a_row4_col7, #T_02e2a_row4_col8, #T_02e2a_row4_col9, #T_02e2a_row4_col10, #T_02e2a_row4_col11, #T_02e2a_row4_col12, #T_02e2a_row4_col13, #T_02e2a_row4_col14, #T_02e2a_row4_col15, #T_02e2a_row4_col16, #T_02e2a_row4_col17, #T_02e2a_row4_col20, #T_02e2a_row4_col21, #T_02e2a_row4_col22, #T_02e2a_row4_col23, #T_02e2a_row4_col24, #T_02e2a_row4_col25, #T_02e2a_row4_col26, #T_02e2a_row4_col27, #T_02e2a_row4_col28, #T_02e2a_row4_col29 {
#   text-align: left;
# }
# #T_02e2a_row0_col18, #T_02e2a_row0_col19, #T_02e2a_row1_col18, #T_02e2a_row1_col19, #T_02e2a_row2_col18, #T_02e2a_row2_col19, #T_02e2a_row3_col18, #T_02e2a_row3_col19, #T_02e2a_row4_col18, #T_02e2a_row4_col19 {
#   text-align: left;
#   background-color: #f8d7da;
# }
# </style>
# <table id="T_02e2a" class="dataframe">
#   <caption>Primeras filas del dataset de Créditos</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_02e2a_level0_col0" class="col_heading level0 col0" >Cliente</th>
#       <th id="T_02e2a_level0_col1" class="col_heading level0 col1" >Tipo_identificacion</th>
#       <th id="T_02e2a_level0_col2" class="col_heading level0 col2" >ID_Estudiante</th>
#       <th id="T_02e2a_level0_col3" class="col_heading level0 col3" >Credito</th>
#       <th id="T_02e2a_level0_col4" class="col_heading level0 col4" >Contar </th>
#       <th id="T_02e2a_level0_col5" class="col_heading level0 col5" >Linea_credito</th>
#       <th id="T_02e2a_level0_col6" class="col_heading level0 col6" >Descripcion_linea_credito</th>
#       <th id="T_02e2a_level0_col7" class="col_heading level0 col7" >Nota_debito</th>
#       <th id="T_02e2a_level0_col8" class="col_heading level0 col8" >Concepto_nota_debito</th>
#       <th id="T_02e2a_level0_col9" class="col_heading level0 col9" >Nombre_concepto</th>
#       <th id="T_02e2a_level0_col10" class="col_heading level0 col10" >Causa_nota_debito</th>
#       <th id="T_02e2a_level0_col11" class="col_heading level0 col11" >Nombre_causa_nota</th>
#       <th id="T_02e2a_level0_col12" class="col_heading level0 col12" >Valor_nota_debito</th>
#       <th id="T_02e2a_level0_col13" class="col_heading level0 col13" >Valor_pagado_nota_debito</th>
#       <th id="T_02e2a_level0_col14" class="col_heading level0 col14" >Fecha_pago_nota_debito</th>
#       <th id="T_02e2a_level0_col15" class="col_heading level0 col15" >Saldo_nota_debito</th>
#       <th id="T_02e2a_level0_col16" class="col_heading level0 col16" >% Recaudo</th>
#       <th id="T_02e2a_level0_col17" class="col_heading level0 col17" >Fecha_vencimiento_ndb</th>
#       <th id="T_02e2a_level0_col18" class="col_heading level0 col18" >Periodo_facturacion</th>
#       <th id="T_02e2a_level0_col19" class="col_heading level0 col19" >Mes_facturacion</th>
#       <th id="T_02e2a_level0_col20" class="col_heading level0 col20" >Periodo_academico</th>
#       <th id="T_02e2a_level0_col21" class="col_heading level0 col21" >Documento</th>
#       <th id="T_02e2a_level0_col22" class="col_heading level0 col22" >Estado</th>
#       <th id="T_02e2a_level0_col23" class="col_heading level0 col23" >Estado_describe</th>
#       <th id="T_02e2a_level0_col24" class="col_heading level0 col24" >Centro_costo</th>
#       <th id="T_02e2a_level0_col25" class="col_heading level0 col25" >Nombre_centro_costo</th>
#       <th id="T_02e2a_level0_col26" class="col_heading level0 col26" >Fecha_solicitud</th>
#       <th id="T_02e2a_level0_col27" class="col_heading level0 col27" >Fecha_aprobacion</th>
#       <th id="T_02e2a_level0_col28" class="col_heading level0 col28" >Cuotas</th>
#       <th id="T_02e2a_level0_col29" class="col_heading level0 col29" >Periodo </th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_02e2a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_02e2a_row0_col0" class="data row0 col0" >2,030,623</td>
#       <td id="T_02e2a_row0_col1" class="data row0 col1" >CC</td>
#       <td id="T_02e2a_row0_col2" class="data row0 col2" >E00001</td>
#       <td id="T_02e2a_row0_col3" class="data row0 col3" >1</td>
#       <td id="T_02e2a_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_02e2a_row0_col5" class="data row0 col5" >1</td>
#       <td id="T_02e2a_row0_col6" class="data row0 col6" >PREGRADO NORMAL DE 1 A 3 SEMESTRE</td>
#       <td id="T_02e2a_row0_col7" class="data row0 col7" >10,044</td>
#       <td id="T_02e2a_row0_col8" class="data row0 col8" >99</td>
#       <td id="T_02e2a_row0_col9" class="data row0 col9" >CREDITO EDUCATIVO UAO</td>
#       <td id="T_02e2a_row0_col10" class="data row0 col10" >204</td>
#       <td id="T_02e2a_row0_col11" class="data row0 col11" >CUOTA  CAPITAL CREDITO UAO.- PREGRADO</td>
#       <td id="T_02e2a_row0_col12" class="data row0 col12" >600,000</td>
#       <td id="T_02e2a_row0_col13" class="data row0 col13" >600,000</td>
#       <td id="T_02e2a_row0_col14" class="data row0 col14" >2003-01-21 00:00:00</td>
#       <td id="T_02e2a_row0_col15" class="data row0 col15" >0</td>
#       <td id="T_02e2a_row0_col16" class="data row0 col16" >100</td>
#       <td id="T_02e2a_row0_col17" class="data row0 col17" >2002-12-21 00:00:00</td>
#       <td id="T_02e2a_row0_col18" class="data row0 col18" >-</td>
#       <td id="T_02e2a_row0_col19" class="data row0 col19" >-</td>
#       <td id="T_02e2a_row0_col20" class="data row0 co

# %%
# Cartera depurada
estilo_tabla(cartera_df.head(), titulo="Primeras filas del dataset de Cartera Depurada")
# Out:
# <style type="text/css">
# #T_0fce0 caption {
#   color: #2c3e50;
#   font-size: 16px;
#   font-weight: bold;
#   text-align: left;
#   margin-bottom: 10px;
# }
# #T_0fce0 th {
#   background-color: #2c3e50;
#   color: white;
#   font-weight: bold;
#   border: 1px solid #ddd;
#   padding: 5px;
# }
# #T_0fce0 td {
#   border: 1px solid #ddd;
#   padding: 5px;
# }
# #T_0fce0_row0_col0, #T_0fce0_row0_col1, #T_0fce0_row0_col2, #T_0fce0_row0_col3, #T_0fce0_row0_col4, #T_0fce0_row0_col5, #T_0fce0_row0_col6, #T_0fce0_row0_col7, #T_0fce0_row0_col8, #T_0fce0_row0_col9, #T_0fce0_row0_col10, #T_0fce0_row0_col11, #T_0fce0_row0_col12, #T_0fce0_row0_col13, #T_0fce0_row0_col14, #T_0fce0_row0_col15, #T_0fce0_row0_col16, #T_0fce0_row0_col17, #T_0fce0_row0_col18, #T_0fce0_row0_col19, #T_0fce0_row0_col26, #T_0fce0_row0_col27, #T_0fce0_row0_col28, #T_0fce0_row0_col29, #T_0fce0_row0_col30, #T_0fce0_row0_col31, #T_0fce0_row0_col32, #T_0fce0_row0_col33, #T_0fce0_row0_col34, #T_0fce0_row0_col35, #T_0fce0_row0_col36, #T_0fce0_row0_col37, #T_0fce0_row0_col38, #T_0fce0_row0_col39, #T_0fce0_row0_col40, #T_0fce0_row0_col41, #T_0fce0_row0_col42, #T_0fce0_row0_col43, #T_0fce0_row0_col44, #T_0fce0_row0_col45, #T_0fce0_row0_col46, #T_0fce0_row0_col47, #T_0fce0_row0_col48, #T_0fce0_row0_col49, #T_0fce0_row0_col51, #T_0fce0_row0_col52, #T_0fce0_row0_col53, #T_0fce0_row0_col54, #T_0fce0_row0_col55, #T_0fce0_row0_col56, #T_0fce0_row0_col61, #T_0fce0_row1_col0, #T_0fce0_row1_col1, #T_0fce0_row1_col2, #T_0fce0_row1_col3, #T_0fce0_row1_col4, #T_0fce0_row1_col5, #T_0fce0_row1_col6, #T_0fce0_row1_col7, #T_0fce0_row1_col8, #T_0fce0_row1_col9, #T_0fce0_row1_col10, #T_0fce0_row1_col11, #T_0fce0_row1_col12, #T_0fce0_row1_col13, #T_0fce0_row1_col14, #T_0fce0_row1_col15, #T_0fce0_row1_col16, #T_0fce0_row1_col17, #T_0fce0_row1_col18, #T_0fce0_row1_col19, #T_0fce0_row1_col20, #T_0fce0_row1_col21, #T_0fce0_row1_col22, #T_0fce0_row1_col23, #T_0fce0_row1_col24, #T_0fce0_row1_col25, #T_0fce0_row1_col29, #T_0fce0_row1_col30, #T_0fce0_row1_col31, #T_0fce0_row1_col32, #T_0fce0_row1_col33, #T_0fce0_row1_col34, #T_0fce0_row1_col35, #T_0fce0_row1_col36, #T_0fce0_row1_col37, #T_0fce0_row1_col38, #T_0fce0_row1_col39, #T_0fce0_row1_col40, #T_0fce0_row1_col41, #T_0fce0_row1_col42, #T_0fce0_row1_col43, #T_0fce0_row1_col44, #T_0fce0_row1_col45, #T_0fce0_row1_col46, #T_0fce0_row1_col47, #T_0fce0_row1_col48, #T_0fce0_row1_col49, #T_0fce0_row1_col51, #T_0fce0_row1_col52, #T_0fce0_row1_col53, #T_0fce0_row1_col54, #T_0fce0_row1_col55, #T_0fce0_row1_col56, #T_0fce0_row1_col61, #T_0fce0_row1_col62, #T_0fce0_row1_col63, #T_0fce0_row1_col64, #T_0fce0_row1_col65, #T_0fce0_row2_col0, #T_0fce0_row2_col1, #T_0fce0_row2_col2, #T_0fce0_row2_col3, #T_0fce0_row2_col4, #T_0fce0_row2_col5, #T_0fce0_row2_col6, #T_0fce0_row2_col7, #T_0fce0_row2_col8, #T_0fce0_row2_col9, #T_0fce0_row2_col10, #T_0fce0_row2_col11, #T_0fce0_row2_col12, #T_0fce0_row2_col13, #T_0fce0_row2_col14, #T_0fce0_row2_col15, #T_0fce0_row2_col16, #T_0fce0_row2_col17, #T_0fce0_row2_col18, #T_0fce0_row2_col19, #T_0fce0_row2_col20, #T_0fce0_row2_col21, #T_0fce0_row2_col22, #T_0fce0_row2_col23, #T_0fce0_row2_col24, #T_0fce0_row2_col25, #T_0fce0_row2_col29, #T_0fce0_row2_col30, #T_0fce0_row2_col31, #T_0fce0_row2_col32, #T_0fce0_row2_col33, #T_0fce0_row2_col34, #T_0fce0_row2_col35, #T_0fce0_row2_col36, #T_0fce0_row2_col37, #T_0fce0_row2_col38, #T_0fce0_row2_col39, #T_0fce0_row2_col40, #T_0fce0_row2_col41, #T_0fce0_row2_col42, #T_0fce0_row2_col43, #T_0fce0_row2_col44, #T_0fce0_row2_col45, #T_0fce0_row2_col46, #T_0fce0_row2_col47, #T_0fce0_row2_col48, #T_0fce0_row2_col49, #T_0fce0_row2_col51, #T_0fce0_row2_col52, #T_0fce0_row2_col53, #T_0fce0_row2_col54, #T_0fce0_row2_col55, #T_0fce0_row2_col56, #T_0fce0_row2_col61, #T_0fce0_row2_col62, #T_0fce0_row2_col63, #T_0fce0_row2_col64, #T_0fce0_row2_col65, #T_0fce0_row3_col0, #T_0fce0_row3_col1, #T_0fce0_row3_col2, #T_0fce0_row3_col3, #T_0fce0_row3_col4, #T_0fce0_row3_col5, #T_0fce0_row3_col6, #T_0fce0_row3_col7, #T_0fce0_row3_col8, #T_0fce0_row3_col9, #T_0fce0_row3_col10, #T_0fce0_row3_col11, #T_0fce0_row3_col12, #T_0fce0_row3_col13, #T_0fce0_row3_col14, #T_0fce0_row3_col15, #T_0fce0_row3_col16, #T_0fce0_row3_col17, #T_0fce0_row3_col18, #T_0fce0_row3_col19, #T_0fce0_row3_col20, #T_0fce0_row3_col21, #T_0fce0_row3_col22, #T_0fce0_row3_col23, #T_0fce0_row3_col24, #T_0fce0 ...
#   text-align: left;
# }
# #T_0fce0_row0_col20, #T_0fce0_row0_col21, #T_0fce0_row0_col22, #T_0fce0_row0_col23, #T_0fce0_row0_col24, #T_0fce0_row0_col25, #T_0fce0_row0_col50, #T_0fce0_row0_col57, #T_0fce0_row0_col58, #T_0fce0_row0_col59, #T_0fce0_row0_col60, #T_0fce0_row0_col62, #T_0fce0_row0_col63, #T_0fce0_row0_col64, #T_0fce0_row0_col65, #T_0fce0_row1_col26, #T_0fce0_row1_col27, #T_0fce0_row1_col28, #T_0fce0_row1_col50, #T_0fce0_row1_col57, #T_0fce0_row1_col58, #T_0fce0_row1_col59, #T_0fce0_row1_col60, #T_0fce0_row2_col26, #T_0fce0_row2_col27, #T_0fce0_row2_col28, #T_0fce0_row2_col50, #T_0fce0_row2_col57, #T_0fce0_row2_col58, #T_0fce0_row2_col59, #T_0fce0_row2_col60, #T_0fce0_row3_col26, #T_0fce0_row3_col27, #T_0fce0_row3_col28, #T_0fce0_row3_col50, #T_0fce0_row3_col57, #T_0fce0_row3_col58, #T_0fce0_row3_col59, #T_0fce0_row3_col60, #T_0fce0_row4_col26, #T_0fce0_row4_col27, #T_0fce0_row4_col28, #T_0fce0_row4_col50, #T_0fce0_row4_col57, #T_0fce0_row4_col58, #T_0fce0_row4_col59, #T_0fce0_row4_col60 {
#   text-align: left;
#   background-color: #f8d7da;
# }
# </style>
# <table id="T_0fce0" class="dataframe">
#   <caption>Primeras filas del dataset de Cartera Depurada</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0fce0_level0_col0" class="col_heading level0 col0" >CLIENTE</th>
#       <th id="T_0fce0_level0_col1" class="col_heading level0 col1" >TIPO ID</th>
#       <th id="T_0fce0_level0_col2" class="col_heading level0 col2" >ID_Estudiante</th>
#       <th id="T_0fce0_level0_col3" class="col_heading level0 col3" > # REG</th>
#       <th id="T_0fce0_level0_col4" class="col_heading level0 col4" >EDAD CARTERA</th>
#       <th id="T_0fce0_level0_col5" class="col_heading level0 col5" >NOMBRE EDAD</th>
#       <th id="T_0fce0_level0_col6" cla

# %%
# Info pagares
estilo_tabla(pagares_df.head(), titulo="Primeras filas del dataset de Info pagares")
# Out:
# <style type="text/css">
# #T_369d8 caption {
#   color: #2c3e50;
#   font-size: 16px;
#   font-weight: bold;
#   text-align: left;
#   margin-bottom: 10px;
# }
# #T_369d8 th {
#   background-color: #2c3e50;
#   color: white;
#   font-weight: bold;
#   border: 1px solid #ddd;
#   padding: 5px;
# }
# #T_369d8 td {
#   border: 1px solid #ddd;
#   padding: 5px;
# }
# #T_369d8_row0_col0, #T_369d8_row0_col1, #T_369d8_row0_col2, #T_369d8_row0_col3, #T_369d8_row0_col4, #T_369d8_row0_col5, #T_369d8_row1_col0, #T_369d8_row1_col1, #T_369d8_row1_col2, #T_369d8_row1_col3, #T_369d8_row1_col4, #T_369d8_row1_col5, #T_369d8_row1_col9, #T_369d8_row2_col0, #T_369d8_row2_col1, #T_369d8_row2_col2, #T_369d8_row2_col3, #T_369d8_row2_col4, #T_369d8_row2_col5, #T_369d8_row3_col0, #T_369d8_row3_col1, #T_369d8_row3_col2, #T_369d8_row3_col3, #T_369d8_row3_col4, #T_369d8_row3_col5, #T_369d8_row4_col0, #T_369d8_row4_col1, #T_369d8_row4_col2, #T_369d8_row4_col3, #T_369d8_row4_col4, #T_369d8_row4_col5 {
#   text-align: left;
# }
# #T_369d8_row0_col6, #T_369d8_row0_col7, #T_369d8_row0_col8, #T_369d8_row0_col9, #T_369d8_row1_col6, #T_369d8_row1_col7, #T_369d8_row1_col8, #T_369d8_row2_col6, #T_369d8_row2_col7, #T_369d8_row2_col8, #T_369d8_row2_col9, #T_369d8_row3_col6, #T_369d8_row3_col7, #T_369d8_row3_col8, #T_369d8_row3_col9, #T_369d8_row4_col6, #T_369d8_row4_col7, #T_369d8_row4_col8, #T_369d8_row4_col9 {
#   text-align: left;
#   background-color: #f8d7da;
# }
# </style>
# <table id="T_369d8" class="dataframe">
#   <caption>Primeras filas del dataset de Info pagares</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_369d8_level0_col0" class="col_heading level0 col0" >ID CRÉDITO</th>
#       <th id="T_369d8_level0_col1" class="col_heading level0 col1" >ID_Estudiante</th>
#       <th id="T_369d8_level0_col2" class="col_heading level0 col2" >Sexo</th>
#       <th id="T_369d8_level0_col3" class="col_heading level0 col3" >Estrato</th>
#       <th id="T_369d8_level0_col4" class="col_heading level0 col4" >Departamento</th>
#       <th id="T_369d8_level0_col5" class="col_heading level0 col5" >Pais Nacimiento</th>
#       <th id="T_369d8_level0_col6" class="col_heading level0 col6" >Primiparo</th>
#       <th id="T_369d8_level0_col7" class="col_heading level0 col7" >Estado_est</th>
#       <th id="T_369d8_level0_col8" class="col_heading level0 col8" >Graduado</th>
#       <th id="T_369d8_level0_col9" class="col_heading level0 col9" >Cargo_codeudor</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_369d8_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_369d8_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_369d8_row0_col1" class="data row0 col1" >E00001</td>
#       <td id="T_369d8_row0_col2" class="data row0 col2" >FEM</td>
#       <td id="T_369d8_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_369d8_row0_col4" class="data row0 col4" >VALLE DEL CAUCA</td>
#       <td id="T_369d8_row0_col5" class="data row0 col5" >COLOMBIA</td>
#       <td id="T_369d8_row0_col6" class="data row0 col6" >-</td>
#       <td id="T_369d8_row0_col7" class="data row0 col7" >-</td>
#       <td id="T_369d8_row0_col8" class="data row0 col8" >-</td>
#       <td id="T_369d8_row0_col9" class="data row0 col9" >-</td>
#     </tr>
#     <tr>
#       <th id="T_369d8_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_369d8_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_369d8_row1_col1" class="data row1 col1" >E00002</td>
#       <td id="T_369d8_row1_col2" class="data row1 col2" >MAS</td>
#       <td id="T_369d8_row1_col3" class="data row1 col3" >0</td>
#       <td id="T_369d8_row1_col4" class="data row1 col4" >VALLE DEL CAUCA</td>
#       <td id="T_369d8_row1_col5" class="data row1 col5" >COLOMBIA</td>
#       <td id="T_369d8_row1_col6" class="data row1 col6" >-</td>
#       <td id="T_369d8_row1_col7" class="data row1 col7" >-</td>
#       <td id="T_369d8_row1_col8" class="data row1 col8" >-</td>
#       <td id="T_369d8_row1_col9" class="data row1 col9" >Coo. de Seguridad</td>
#     </tr>
#     <tr>
#       <th id="T_369d8_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_369d8_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_369d8_row2_col1" class="data row2 col1" >E00003</td>
#       <td id="T_369d8_row2_col2" class="data row2 col2" >MAS</td>
#       <td id="T_369d8_row2_col3" class="data row2 col3" >0</td>
#       <td id="T_369d8_row2_col4" class="data row2 col4" >VALLE DEL CAUCA</td>
#       <td id="T_369d8_row2_col5" class="data row2 col5" >COLOMBIA</td>
#       <td id="T_369d8_row2_col6" class="data row2 col6" >-</td>
#       <td id="T_369d8_row2_col7" class="data row2 col7" >-</td>
#       <td id="T_369d8_row2_col8" class="data row2 col8" >-</td>
#       <td id="T_369d8_row2_col9" class="data row2 col9" >-</td>
#     </tr>
#     <tr>
#       <th id="T_369d8_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_369d8_row3_col0" class="data row3 col0" >4</td>
#       <td id="T_369d8_row3_col1" class="data row3 col1" >E00004</td>
#       <td id="T_369d8_row3_col2" class="data row3 col2" >MAS</td>
#       <td id="T_369d8_row3_col3" class="data row3 col3" >0</td>
#       <td id="T_369d8_row3_col4" class="data row3 col4" >VALLE DEL CAUCA</td>
#       <td id="T_369d8_row3_col5" class="data row3 col5" >COLOMBIA</td>
#       <td id="T_369d8_row3_col6" class="data row3 col6" >-</td>
#       <td id="T_369d8_row3_col7" class="data row3 col7" >-</td>
#       <td id="T_369d8_row3_col8" class="data row3 col8" >-</td>
#       <td id="T_369d8_row3_col9" class="data row3 col9" >-</td>
#     </tr>
#     <tr>
#       <th id="T_369d8_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_369d8_row4_col0" class="data row4 col0" >5</td>
#       <td id="T_369d8_row4_col1" class="data row4 col1" >E00005</td>
#       <td id="T_369d8_row4_col2" class="data row4 col2" >MAS</td>
#       <td id="T_369d8_row4_col3" class="data row4 col3" >6</td>
#       <td id="T_369d8_row4_col4" class="data row4 col4" >VALLE DEL CAUCA</td>
#       <td id="T_369d8_row4_col5" class="data row4 col5" >COLOMBIA</td>
#       <td id="T_369d8_row4_col6" class="data row4 col6" >-</td>
#       <td id="T_369d8_row4_col7" class="data row4 col7" >-</td>
#       <td id="T_369d8_row4_col8" class="data row4 col8" >-</td>
#       <td id="T_369d8_row4_col9" class="data row4 col9" >-</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Información general de variables:

# %%
# Tabla resumen de info para Créditos

info_creditos = pd.DataFrame({
    "columna": creditos_df.columns,
    "tipo_dato": creditos_df.dtypes.astype(str),
    "n_nulos": creditos_df.isna().sum(),
    "%_nulos": (creditos_df.isna().mean() * 100).round(2)
})

# Ordenamos por % de nulos descendente para ver primero las variables más problemáticas
info_creditos = info_creditos.sort_values("%_nulos", ascending=False).reset_index(drop=True)

estilo_tabla(info_creditos, titulo="Información general del dataset de Créditos")
# Out:
# <style type="text/css">
# #T_ed712 caption {
#   color: #2c3e50;
#   font-size: 16px;
#   font-weight: bold;
#   text-align: left;
#   margin-bottom: 10px;
# }
# #T_ed712 th {
#   background-color: #2c3e50;
#   color: white;
#   font-weight: bold;
#   border: 1px solid #ddd;
#   padding: 5px;
# }
# #T_ed712 td {
#   border: 1px solid #ddd;
#   padding: 5px;
# }
# #T_ed712_row0_col0, #T_ed712_row0_col1, #T_ed712_row0_col2, #T_ed712_row0_col3, #T_ed712_row1_col0, #T_ed712_row1_col1, #T_ed712_row1_col2, #T_ed712_row1_col3, #T_ed712_row2_col0, #T_ed712_row2_col1, #T_ed712_row2_col2, #T_ed712_row2_col3, #T_ed712_row3_col0, #T_ed712_row3_col1, #T_ed712_row3_col2, #T_ed712_row3_col3, #T_ed712_row4_col0, #T_ed712_row4_col1, #T_ed712_row4_col2, #T_ed712_row4_col3, #T_ed712_row5_col0, #T_ed712_row5_col1, #T_ed712_row5_col2, #T_ed712_row5_col3, #T_ed712_row6_col0, #T_ed712_row6_col1, #T_ed712_row6_col2, #T_ed712_row6_col3, #T_ed712_row7_col0, #T_ed712_row7_col1, #T_ed712_row7_col2, #T_ed712_row7_col3, #T_ed712_row8_col0, #T_ed712_row8_col1, #T_ed712_row8_col2, #T_ed712_row8_col3, #T_ed712_row9_col0, #T_ed712_row9_col1, #T_ed712_row9_col2, #T_ed712_row9_col3, #T_ed712_row10_col0, #T_ed712_row10_col1, #T_ed712_row10_col2, #T_ed712_row10_col3, #T_ed712_row11_col0, #T_ed712_row11_col1, #T_ed712_row11_col2, #T_ed712_row11_col3, #T_ed712_row12_col0, #T_ed712_row12_col1, #T_ed712_row12_col2, #T_ed712_row12_col3, #T_ed712_row13_col0, #T_ed712_row13_col1, #T_ed712_row13_col2, #T_ed712_row13_col3, #T_ed712_row14_col0, #T_ed712_row14_col1, #T_ed712_row14_col2, #T_ed712_row14_col3, #T_ed712_row15_col0, #T_ed712_row15_col1, #T_ed712_row15_col2, #T_ed712_row15_col3, #T_ed712_row16_col0, #T_ed712_row16_col1, #T_ed712_row16_col2, #T_ed712_row16_col3, #T_ed712_row17_col0, #T_ed712_row17_col1, #T_ed712_row17_col2, #T_ed712_row17_col3, #T_ed712_row18_col0, #T_ed712_row18_col1, #T_ed712_row18_col2, #T_ed712_row18_col3, #T_ed712_row19_col0, #T_ed712_row19_col1, #T_ed712_row19_col2, #T_ed712_row19_col3, #T_ed712_row20_col0, #T_ed712_row20_col1, #T_ed712_row20_col2, #T_ed712_row20_col3, #T_ed712_row21_col0, #T_ed712_row21_col1, #T_ed712_row21_col2, #T_ed712_row21_col3, #T_ed712_row22_col0, #T_ed712_row22_col1, #T_ed712_row22_col2, #T_ed712_row22_col3, #T_ed712_row23_col0, #T_ed712_row23_col1, #T_ed712_row23_col2, #T_ed712_row23_col3, #T_ed712_row24_col0, #T_ed712_row24_col1, #T_ed712_row24_col2, #T_ed712_row24_col3, #T_ed712_row25_col0, #T_ed712_row25_col1, #T_ed712_row25_col2, #T_ed712_row25_col3, #T_ed712_row26_col0, #T_ed712_row26_col1, #T_ed712_row26_col2, #T_ed712_row26_col3, #T_ed712_row27_col0, #T_ed712_row27_col1, #T_ed712_row27_col2, #T_ed712_row27_col3, #T_ed712_row28_col0, #T_ed712_row28_col1, #T_ed712_row28_col2, #T_ed712_row28_col3, #T_ed712_row29_col0, #T_ed712_row29_col1, #T_ed712_row29_col2, #T_ed712_row29_col3 {
#   text-align: left;
# }
# </style>
# <table id="T_ed712" class="dataframe">
#   <caption>Información general del dataset de Créditos</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ed712_level0_col0" class="col_heading level0 col0" >columna</th>
#       <th id="T_ed712_level0_col1" class="col_heading level0 col1" >tipo_dato</th>
#       <th id="T_ed712_level0_col2" class="col_heading level0 col2" >n_nulos</th>
#       <th id="T_ed712_level0_col3" class="col_heading level0 col3" >%_nulos</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ed712_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ed712_row0_col0" class="data row0 col0" >Periodo_facturacion</td>
#       <td id="T_ed712_row0_col1" class="data row0 col1" >object</td>
#       <td id="T_ed712_row0_col2" class="data row0 col2" >47,231</td>
#       <td id="T_ed712_row0_col3" class="data row0 col3" >12</td>
#     </tr>
#     <tr>
#       <th id="T_ed712_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_ed712_row1_col0" class="data row1 col0" >Mes_facturacion</td>
#       <td id="T_ed712_row1_col1" class="data row1 col1" >object</td>
#       <td id="T_ed712_row1_col2" class="data row1 col2" >47,231</td>
#       <td id="T_ed712_row1_col3" class="data row1 col3" >12</td>
#     </tr>
#     <tr>
#       <th id="T_ed712_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_ed712_row2_col0" class="data row2 col0" >Documento</td>
#       <td id="T_ed712_row2_col1" class="data row2 col1" >object</td>
#       <td id="T_ed712_row2_col2" class="data row2 col2" >41,123</td>
#       <td id="T_ed712_row2_col3" class="data row2 col3" >10</td>
#     </tr>
#     <tr>
#       <th id="T_ed712_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_ed712_row3_col0" class="data row3 col0" >Fecha_pago_nota_debito</td>
#       <td id="T_ed712_row3_col1" class="data row3 col1" >datetime64[ns]</td>
#       <td id="T_ed712_row3_col2" class="data row3 col2" >29,478</td>
#       <td id="T_ed712_row3_col3" class="data row3 col3" >7</td>
#     </tr>
#     <tr>
#       <th id="T_ed712_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_ed712_row4_col0" class="data row4 col0" >Cliente</td>
#       <td id="T_ed712_row4_col1" class="data row4 col1" >int64</td>
#       <td id="T_ed712_row4_col2" class="data row4 col2" >0</td>
#       <td id="T_ed712_row4_col3" class="data row4 col3" >0</td>
#     </tr>
#     <tr>
#       <th id="T_ed712_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_ed712_row5_col0" class="data row5 col0" >Tipo_identificacion</td>
#       <td id="T_ed712_row5_col1" class="data row5 col1" >object</td>
#       <td id="T_ed712_row5_col2" class="data row5 col2" >0</td>
#       <td id="T_ed712_row5_col3" class="data row5 col3" >0</td>
#     </tr>
#     <tr>
#       <th id="T_ed712_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_ed712_row6_col0" class="data row6 col0" >Descripcion_linea_credito</td>
#       <td id="T_ed712_row6_col1" class="data row6 col1" >object</td>
#       <td id="T_ed712_row6_col2" class="data row6 col2" >0</td>
#       <td id="T_ed712_row6_col3" class="data row6 col3" >0</td>
#     </tr>
#     <tr>
#       <th id="T_ed712_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_ed712_row7_col0" class="data row7 col0" >Nota_debito</td>
#       <td id="T_ed712_row7_col1" class="data row7 col1" >int64</td>
#       <td id="T_ed712_row7_col2" class="data row7 col2" >0</td>
#       <td id="T_ed712_row7_col3" class="data row7 col3" >0</td>
#     </tr>
#     <tr>
#       <th id="T_ed712_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_ed712_row8_col0" class="data row8 col0" >Concepto_nota_debito</td>
#       <td id="T_ed712_row8_col1" class="data row8 col1" >int64</td>
#       <td id="T_ed712_row8_col2" class="data row8 col2" >0</td>
#       <td id="T_ed712_row8_col3" class="data row8 col3" >0</td>
#     </tr>
#     <tr>
#       <th id="T_ed712_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_ed712_row9_col0" class="data row9 col0" >Nombre_concepto</td>
#       <td id="T_ed712_row9_col1" class="data row9 col1" >object</td>
#       <td id="T_ed712_row9_col2" class="data row9 col2" >0</td>
#       <td id="T_ed712_row9_col3" class="data row9 col3" >0</td>
#     </tr>
#     <tr>
#       <th id="T_ed712_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_ed712_row10_col0" class="data row10 col0" >ID_Estudiante</td>
#       <td id="T_ed712_row10_col1" class="data row10 col1" >object</td>
#       <td id="T_ed712_row10_col2" class="data row10 col2" >0</td>
#       <td id="T_ed712_row10_col3" class="data row10 col3" >0</td>
#     </tr>
#     <tr>
#       <th id="T_ed712_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_ed712_row11_col0" class="data row11 col0" >Credito</td>
#       <td id="T_ed712_row11_col1" class="data row11 col1" >int64</td>
#       <td id="T_ed712_row11_col2" class="data row11 col2" >0</td>
#       <td id="T_ed712_row11_col3" class="data row11 col3" >0</td>
#     </tr>
#     <tr>
#       <th id="T_ed712_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_ed712_row12_col0" class="data row12 col0" >Contar </td

# %%
# Tabla resumen de info para Cartera Depurada

info_cartera = pd.DataFrame({
    "columna": cartera_df.columns,
    "tipo_dato": cartera_df.dtypes.astype(str),
    "n_nulos": cartera_df.isna().sum(),
    "%_nulos": (cartera_df.isna().mean() * 100).round(2)
})

info_cartera = info_cartera.sort_values("%_nulos", ascending=False).reset_index(drop=True)

estilo_tabla(info_cartera, titulo="Información general del dataset de Cartera Depurada")
# Out:
# <style type="text/css">
# #T_a5ff6 caption {
#   color: #2c3e50;
#   font-size: 16px;
#   font-weight: bold;
#   text-align: left;
#   margin-bottom: 10px;
# }
# #T_a5ff6 th {
#   background-color: #2c3e50;
#   color: white;
#   font-weight: bold;
#   border: 1px solid #ddd;
#   padding: 5px;
# }
# #T_a5ff6 td {
#   border: 1px solid #ddd;
#   padding: 5px;
# }
# #T_a5ff6_row0_col0, #T_a5ff6_row0_col1, #T_a5ff6_row0_col2, #T_a5ff6_row0_col3, #T_a5ff6_row1_col0, #T_a5ff6_row1_col1, #T_a5ff6_row1_col2, #T_a5ff6_row1_col3, #T_a5ff6_row2_col0, #T_a5ff6_row2_col1, #T_a5ff6_row2_col2, #T_a5ff6_row2_col3, #T_a5ff6_row3_col0, #T_a5ff6_row3_col1, #T_a5ff6_row3_col2, #T_a5ff6_row3_col3, #T_a5ff6_row4_col0, #T_a5ff6_row4_col1, #T_a5ff6_row4_col2, #T_a5ff6_row4_col3, #T_a5ff6_row5_col0, #T_a5ff6_row5_col1, #T_a5ff6_row5_col2, #T_a5ff6_row5_col3, #T_a5ff6_row6_col0, #T_a5ff6_row6_col1, #T_a5ff6_row6_col2, #T_a5ff6_row6_col3, #T_a5ff6_row7_col0, #T_a5ff6_row7_col1, #T_a5ff6_row7_col2, #T_a5ff6_row7_col3, #T_a5ff6_row8_col0, #T_a5ff6_row8_col1, #T_a5ff6_row8_col2, #T_a5ff6_row8_col3, #T_a5ff6_row9_col0, #T_a5ff6_row9_col1, #T_a5ff6_row9_col2, #T_a5ff6_row9_col3, #T_a5ff6_row10_col0, #T_a5ff6_row10_col1, #T_a5ff6_row10_col2, #T_a5ff6_row10_col3, #T_a5ff6_row11_col0, #T_a5ff6_row11_col1, #T_a5ff6_row11_col2, #T_a5ff6_row11_col3, #T_a5ff6_row12_col0, #T_a5ff6_row12_col1, #T_a5ff6_row12_col2, #T_a5ff6_row12_col3, #T_a5ff6_row13_col0, #T_a5ff6_row13_col1, #T_a5ff6_row13_col2, #T_a5ff6_row13_col3, #T_a5ff6_row14_col0, #T_a5ff6_row14_col1, #T_a5ff6_row14_col2, #T_a5ff6_row14_col3, #T_a5ff6_row15_col0, #T_a5ff6_row15_col1, #T_a5ff6_row15_col2, #T_a5ff6_row15_col3, #T_a5ff6_row16_col0, #T_a5ff6_row16_col1, #T_a5ff6_row16_col2, #T_a5ff6_row16_col3, #T_a5ff6_row17_col0, #T_a5ff6_row17_col1, #T_a5ff6_row17_col2, #T_a5ff6_row17_col3, #T_a5ff6_row18_col0, #T_a5ff6_row18_col1, #T_a5ff6_row18_col2, #T_a5ff6_row18_col3, #T_a5ff6_row19_col0, #T_a5ff6_row19_col1, #T_a5ff6_row19_col2, #T_a5ff6_row19_col3, #T_a5ff6_row20_col0, #T_a5ff6_row20_col1, #T_a5ff6_row20_col2, #T_a5ff6_row20_col3, #T_a5ff6_row21_col0, #T_a5ff6_row21_col1, #T_a5ff6_row21_col2, #T_a5ff6_row21_col3, #T_a5ff6_row22_col0, #T_a5ff6_row22_col1, #T_a5ff6_row22_col2, #T_a5ff6_row22_col3, #T_a5ff6_row23_col0, #T_a5ff6_row23_col1, #T_a5ff6_row23_col2, #T_a5ff6_row23_col3, #T_a5ff6_row24_col0, #T_a5ff6_row24_col1, #T_a5ff6_row24_col2, #T_a5ff6_row24_col3, #T_a5ff6_row25_col0, #T_a5ff6_row25_col1, #T_a5ff6_row25_col2, #T_a5ff6_row25_col3, #T_a5ff6_row26_col0, #T_a5ff6_row26_col1, #T_a5ff6_row26_col2, #T_a5ff6_row26_col3, #T_a5ff6_row27_col0, #T_a5ff6_row27_col1, #T_a5ff6_row27_col2, #T_a5ff6_row27_col3, #T_a5ff6_row28_col0, #T_a5ff6_row28_col1, #T_a5ff6_row28_col2, #T_a5ff6_row28_col3, #T_a5ff6_row29_col0, #T_a5ff6_row29_col1, #T_a5ff6_row29_col2, #T_a5ff6_row29_col3, #T_a5ff6_row30_col0, #T_a5ff6_row30_col1, #T_a5ff6_row30_col2, #T_a5ff6_row30_col3, #T_a5ff6_row31_col0, #T_a5ff6_row31_col1, #T_a5ff6_row31_col2, #T_a5ff6_row31_col3, #T_a5ff6_row32_col0, #T_a5ff6_row32_col1, #T_a5ff6_row32_col2, #T_a5ff6_row32_col3, #T_a5ff6_row33_col0, #T_a5ff6_row33_col1, #T_a5ff6_row33_col2, #T_a5ff6_row33_col3, #T_a5ff6_row34_col0, #T_a5ff6_row34_col1, #T_a5ff6_row34_col2, #T_a5ff6_row34_col3, #T_a5ff6_row35_col0, #T_a5ff6_row35_col1, #T_a5ff6_row35_col2, #T_a5ff6_row35_col3, #T_a5ff6_row36_col0, #T_a5ff6_row36_col1, #T_a5ff6_row36_col2, #T_a5ff6_row36_col3, #T_a5ff6_row37_col0, #T_a5ff6_row37_col1, #T_a5ff6_row37_col2, #T_a5ff6_row37_col3, #T_a5ff6_row38_col0, #T_a5ff6_row38_col1, #T_a5ff6_row38_col2, #T_a5ff6_row38_col3, #T_a5ff6_row39_col0, #T_a5ff6_row39_col1, #T_a5ff6_row39_col2, #T_a5ff6_row39_col3, #T_a5ff6_row40_col0, #T_a5ff6_row40_col1, #T_a5ff6_row40_col2, #T_a5ff6_row40_col3, #T_a5ff6_row41_col0, #T_a5ff6_row41_col1, #T_a5ff6_row41_col2, #T_a5ff6_row41_col3, #T_a5ff6_row42_col0, #T_a5ff6_row42_col1, #T_a5ff6_row42_col2, #T_a5ff6_row42_col3, #T_a5ff6_row43_col0, #T_a5ff6_row43_col1, #T_a5ff6_row43_col2, #T_a5ff6_row43_col3, #T_a5ff6_row44_col0, #T_a5ff6_row44_col1, #T_a5ff6_row44_col2, #T_a5ff6_row44_col3, #T_a5ff6_row45_col0, #T_a5ff6_row45_col1, #T_a5ff6_row45_col2, #T_a5ff6_row45_col3, #T_a5ff6_row46_col0, #T_a5ff6_row46_col1, #T_a5ff6_row46_col2, #T_a5ff6_row46_col3, #T_a5ff6_row47_col0, #T_a5ff6_row47_col1, #T_a5ff6_row47_col2, #T_a5ff6_row47_col3, #T_a5ff6 ...
#   text-align: left;
# }
# </style>
# <table id="T_a5ff6" class="dataframe">
#   <caption>Información general del dataset de Cartera Depurada</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a5ff6_level0_col0" class="col_heading level0 col0" >columna</th>
#       <th id="T_a5ff6_level0_col1" class="col_heading level0 col1" >tipo_dato</th>
#       <th id="T_a5ff6_level0_col2" class="col_heading level0 col2" >n_nulos</th>
#       <th id="T_a5ff6_level0_col3" class="col_heading level0 col3" >%_nulos</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a5ff6_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a5ff6_row0_col0" class="data row0 col0" >FECHA CANCELACIÓN</td>
#       <td id="T_a5ff6_row0_col1" class="data row0 col1" >datetime64[ns]</td>
#       <td id="T_a5ff6_row0_col2" class="data row0 col2" >26,886</td>
#       <td id="T_a5ff6_row0_col3" class="data row0 col3" >98</td>
#     </tr>
#     <tr>
#       <th id="T_a5ff6_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_a5ff6_row1_col0" class="data row1 col0" >DOCUMENTO ORIGEN</td>
#       <td id="T_a5ff6_row1_col1" class="data row1 col1" >object</td>
#       <td id="T_a5ff6_row1_col2" class="data row1 col2" >26,263</td>
#       <td id="T_a5ff6_row1_col3" class="data row1 col3" >96</td>
#     </tr>
#     <tr>
#       <th id="T_a5ff6_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_a5ff6_row2_col0" class="data row2 col0" >ORGANIZACIÓN ORIGEN</td>
#       <td id="T_a5ff6_row2_col1" class="data row2 col1" >float64</td>
#       <td id="T_a5ff6_row2_col2" class="data row2 col2" >26,263</td>
#       <td id="T_a5ff6_row2_col3" class="data row2 col3" >96</td>
#     </tr>
#     <tr>
#       <th id="T_a5ff6_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_a5ff6_row3_col0" class="data row3 col0" >NÚMERO ORIGEN</td>
#       <td id="T_a5ff6_row3_col1" class="data row3 col1" >float64</td>
#       <td id="T_a5ff6_row3_col2" class="data row3 col2" >26,263</td>
#       <td id="T_a5ff6_row3_col3" class="data row3 col3" >96</td>
#     </tr>
#     <tr>
#       <th id="T_a5ff6_level0_row4" class="row_heading level0 row4" >4</th>

# %%
# Tabla resumen de calidad de datos — Info Pagares

info_pagares = pd.DataFrame({
    "columna": pagares_df.columns,
    "tipo_dato": pagares_df.dtypes.astype(str),
    "n_nulos": pagares_df.isna().sum(),
    "%_nulos": (pagares_df.isna().mean() * 100).round(2)
})

info_pagares = info_pagares.sort_values("%_nulos", ascending=False).reset_index(drop=True)

estilo_tabla(info_pagares, titulo="Información general del dataset de Info Pagares")
# Out:
# <style type="text/css">
# #T_97851 caption {
#   color: #2c3e50;
#   font-size: 16px;
#   font-weight: bold;
#   text-align: left;
#   margin-bottom: 10px;
# }
# #T_97851 th {
#   background-color: #2c3e50;
#   color: white;
#   font-weight: bold;
#   border: 1px solid #ddd;
#   padding: 5px;
# }
# #T_97851 td {
#   border: 1px solid #ddd;
#   padding: 5px;
# }
# #T_97851_row0_col0, #T_97851_row0_col1, #T_97851_row0_col2, #T_97851_row0_col3, #T_97851_row1_col0, #T_97851_row1_col1, #T_97851_row1_col2, #T_97851_row1_col3, #T_97851_row2_col0, #T_97851_row2_col1, #T_97851_row2_col2, #T_97851_row2_col3, #T_97851_row3_col0, #T_97851_row3_col1, #T_97851_row3_col2, #T_97851_row3_col3, #T_97851_row4_col0, #T_97851_row4_col1, #T_97851_row4_col2, #T_97851_row4_col3, #T_97851_row5_col0, #T_97851_row5_col1, #T_97851_row5_col2, #T_97851_row5_col3, #T_97851_row6_col0, #T_97851_row6_col1, #T_97851_row6_col2, #T_97851_row6_col3, #T_97851_row7_col0, #T_97851_row7_col1, #T_97851_row7_col2, #T_97851_row7_col3, #T_97851_row8_col0, #T_97851_row8_col1, #T_97851_row8_col2, #T_97851_row8_col3, #T_97851_row9_col0, #T_97851_row9_col1, #T_97851_row9_col2, #T_97851_row9_col3 {
#   text-align: left;
# }
# </style>
# <table id="T_97851" class="dataframe">
#   <caption>Información general del dataset de Info Pagares</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_97851_level0_col0" class="col_heading level0 col0" >columna</th>
#       <th id="T_97851_level0_col1" class="col_heading level0 col1" >tipo_dato</th>
#       <th id="T_97851_level0_col2" class="col_heading level0 col2" >n_nulos</th>
#       <th id="T_97851_level0_col3" class="col_heading level0 col3" >%_nulos</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_97851_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_97851_row0_col0" class="data row0 col0" >Cargo_codeudor</td>
#       <td id="T_97851_row0_col1" class="data row0 col1" >object</td>
#       <td id="T_97851_row0_col2" class="data row0 col2" >203,648</td>
#       <td id="T_97851_row0_col3" class="data row0 col3" >39</td>
#     </tr>
#     <tr>
#       <th id="T_97851_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_97851_row1_col0" class="data row1 col0" >Graduado</td>
#       <td id="T_97851_row1_col1" class="data row1 col1" >object</td>
#       <td id="T_97851_row1_col2" class="data row1 col2" >37,965</td>
#       <td id="T_97851_row1_col3" class="data row1 col3" >7</td>
#     </tr>
#     <tr>
#       <th id="T_97851_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_97851_row2_col0" class="data row2 col0" >Primiparo</td>
#       <td id="T_97851_row2_col1" class="data row2 col1" >object</td>
#       <td id="T_97851_row2_col2" class="data row2 col2" >37,965</td>
#       <td id="T_97851_row2_col3" class="data row2 col3" >7</td>
#     </tr>
#     <tr>
#       <th id="T_97851_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_97851_row3_col0" class="data row3 col0" >Estado_est</td>
#       <td id="T_97851_row3_col1" class="data row3 col1" >object</td>
#       <td id="T_97851_row3_col2" class="data row3 col2" >37,966</td>
#       <td id="T_97851_row3_col3" class="data row3 col3" >7</td>
#     </tr>
#     <tr>
#       <th id="T_97851_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_97851_row4_col0" class="data row4 col0" >ID_Estudiante</td>
#       <td id="T_97851_row4_col1" class="data row4 col1" >object</td>
#       <td id="T_97851_row4_col2" class="data row4 col2" >33,558</td>
#       <td id="T_97851_row4_col3" class="data row4 col3" >6</td>
#     </tr>
#     <tr>
#       <th id="T_97851_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_97851_row5_col0" class="data row5 col0" >Departamento</td>
#       <td id="T_97851_row5_col1" class="data row5 col1" >object</td>
#       <td id="T_97851_row5_col2" class="data row5 col2" >23,530</td>
#       <td id="T_97851_row5_col3" class="data row5 col3" >5</td>
#     </tr>
#     <tr>
#       <th id="T_97851_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_97851_row6_col0" class="data row6 col0" >Estrato</td>
#       <td id="T_97851_row6_col1" class="data row6 col1" >float64</td>
#       <td id="T_97851_row6_col2" class="data row6 col2" >23,530</td>
#       <td id="T_97851_row6_col3" class="data row6 col3" >5</td>
#     </tr>
#     <tr>
#       <th id="T_97851_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_97851_row7_col0" class="data row7 col0" >Pais Nacimiento</td>
#       <td id="T_97851_row7_col1" class="data row7 col1" >object</td>
#       <td id="T_97851_row7_col2" class="data row7 col2" >23,530</td>
#       <td id="T_97851_row7_col3" class="data row7 col3" >5</td>
#     </tr>
#     <tr>
#       <th id="T_97851_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_97851_row8_col0" class="data row8 col0" >ID CRÉDITO</td>
#       <td id="T_97851_row8_col1" class="data row8 col1" >int64</td>
#       <td id="T_97851_row8_col2" class="data row8 col2" >0</td>
#       <td id="T_97851_row8_col3" class="data row8 col3" >0</td>
#     </tr>
#     <tr>
#       <th id="T_97851_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_97851_row9_col0" class="data row9 col0" >Sexo</td>
#       <td id="T_97851_row9_col1" class="data row9 col1" >object</td>
#       <td id="T_97851_row9_col2" class="data row9 col2" >0</td>
#       <td id="T_97851_row9_col3" class="data row9 col3" >0</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Al revisar las tablas de valores nulos en los dos conjuntos de datos (Créditos y Cartera depurada), podemos darnos cuenta de que algunas columnas tienen muchos datos faltantes (nulos), mientras que otras están casi completas.
#
# En el caso de Créditos, hay columnas como `Periodo_facturacion` y `Mes_facturacion` que tienen aproximadamente un 12% de valores nulos, lo que significa que en uno de cada diez registros falta esa información. Otras columnas, como `Documento` y `Fecha_pago_nota_debito`, también tienen un porcentaje menor de datos faltantes, pero no tan crítico.
#
# En Cartera depurada, la situación es aún más notable porque encontramos variables como `FECHA CANCELACIÓN`, `DOCUMENTO ORIGEN` y `NOMBRE REFERENCIA` con más del 90% de valores nulos. Esto quiere decir que, para la mayoría de los registros, esa información no está disponible.
#
# Estos resultados nos indican dos cosas principales:
#
# Hay ciertas variables que tal vez no sean tan relevantes para el análisis, porque apenas tienen información.
#
# En otras, aunque el porcentaje de nulos es menor, deberíamos considerar cómo manejar esos valores faltantes, ya sea completándolos de alguna manera (si es posible) o descartando esas columnas o registros, dependiendo de la importancia que tengan para los modelos o el análisis que queremos hacer.
#
# En resumen, identificar estos valores nulos desde el comienzo nos ayuda a entender la calidad de nuestros datos y decidir, de manera informada, los siguientes pasos para limpiarlos y prepararlos correctamente antes de analizarlos o utilizarlos en modelos predictivos.

# %% [markdown]
# Resumen tamaño de los datasets:

# %%
# Resumen rápido de tamaño de los datasets

resumen_shapes = pd.DataFrame({
    "dataset": ["Créditos", "Cartera depurada", "Info Pagares"],
    "n_filas":  [
        creditos_df.shape[0],
        cartera_df.shape[0],
        pagares_df.shape[0]
    ],
    "n_columnas": [
        creditos_df.shape[1],
        cartera_df.shape[1],
        pagares_df.shape[1]
    ]
})

estilo_tabla(resumen_shapes, titulo="Dimensión de los datasets")
# Out:
# <style type="text/css">
# #T_d76c0 caption {
#   color: #2c3e50;
#   font-size: 16px;
#   font-weight: bold;
#   text-align: left;
#   margin-bottom: 10px;
# }
# #T_d76c0 th {
#   background-color: #2c3e50;
#   color: white;
#   font-weight: bold;
#   border: 1px solid #ddd;
#   padding: 5px;
# }
# #T_d76c0 td {
#   border: 1px solid #ddd;
#   padding: 5px;
# }
# #T_d76c0_row0_col0, #T_d76c0_row0_col1, #T_d76c0_row0_col2, #T_d76c0_row1_col0, #T_d76c0_row1_col1, #T_d76c0_row1_col2, #T_d76c0_row2_col0, #T_d76c0_row2_col1, #T_d76c0_row2_col2 {
#   text-align: left;
# }
# </style>
# <table id="T_d76c0" class="dataframe">
#   <caption>Dimensión de los datasets</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d76c0_level0_col0" class="col_heading level0 col0" >dataset</th>
#       <th id="T_d76c0_level0_col1" class="col_heading level0 col1" >n_filas</th>
#       <th id="T_d76c0_level0_col2" class="col_heading level0 col2" >n_columnas</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d76c0_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d76c0_row0_col0" class="data row0 col0" >Créditos</td>
#       <td id="T_d76c0_row0_col1" class="data row0 col1" >405,829</td>
#       <td id="T_d76c0_row0_col2" class="data row0 col2" >30</td>
#     </tr>
#     <tr>
#       <th id="T_d76c0_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_d76c0_row1_col0" class="data row1 col0" >Cartera depurada</td>
#       <td id="T_d76c0_row1_col1" class="data row1 col1" >27,330</td>
#       <td id="T_d76c0_row1_col2" class="data row1 col2" >66</td>
#     </tr>
#     <tr>
#       <th id="T_d76c0_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_d76c0_row2_col0" class="data row2 col0" >Info Pagares</td>
#       <td id="T_d76c0_row2_col1" class="data row2 col1" >522,286</td>
#       <td id="T_d76c0_row2_col2" class="data row2 col2" >10</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Corrección de tipos de datos:

# %%
# Corrección de tipos de datos en creditos_df

# Limpieza ligera de nombres de columnas (quita espacios)
creditos_df.columns = creditos_df.columns.str.strip()

# Conversión explícita de columnas de fecha
cols_fecha = [
    "Fecha_pago_nota_debito",
    "Fecha_vencimiento_ndb",
    "Fecha_solicitud",
    "Fecha_aprobacion",
]

for col in cols_fecha:
    if col in creditos_df.columns:
        creditos_df[col] = pd.to_datetime(
            creditos_df[col],
            errors="coerce",
            dayfirst=True
        )

# Conversión de columnas numéricas (enteros y floats)

cols_int = [
    "Cliente",
    "Credito",
    "Contar",
    "Nota_debito",
    "Concepto_nota_debito",
    "Causa_nota_debito",
    "Centro_costo",
    "Cuotas",
]

cols_float = [
    "Valor_nota_debito",
    "Valor_pagado_nota_debito",
    "Saldo_nota_debito",
    "% Recaudo",
]

for col in cols_int:
    if col in creditos_df.columns:
        creditos_df[col] = pd.to_numeric(creditos_df[col], errors="coerce").astype("Int64")

for col in cols_float:
    if col in creditos_df.columns:
        creditos_df[col] = pd.to_numeric(creditos_df[col], errors="coerce")

# Conversión de columnas categóricas (incluye IDs anónimos)

cols_categoricas = [
    "Tipo_identificacion",
    "ID_Estudiante",
    "Linea_credito",
    "Descripcion_linea_credito",
    "Nombre_concepto",
    "Nombre_causa_nota",
    "Estado",
    "Estado_describe",
    "Nombre_centro_costo",
]

for col in cols_categoricas:
    if col in creditos_df.columns:
        creditos_df[col] = creditos_df[col].astype("category")

# Tratamiento de columnas de periodo (las dejamos como categóricas)

cols_periodo = [
    "Periodo_facturacion",
    "Mes_facturacion",
    "Periodo_academico",
    "Periodo",
]

for col in cols_periodo:
    if col in creditos_df.columns:
        creditos_df[col] = creditos_df[col].astype("category")

# Documento: mantener como texto (object) o pasarlo a categoría si quieres
if "Documento" in creditos_df.columns:
    creditos_df["Documento"] = creditos_df["Documento"].astype("string")  # texto limpio
    # Si más adelante quieres tratarlo como categórico:
    # creditos_df["Documento"] = creditos_df["Documento"].astype("category")

print("Corrección de tipos completada.")
# Out:
# Corrección de tipos completada.

# %%
tipos_creditos_post = pd.DataFrame({
    "columna": creditos_df.columns,
    "tipo_dato": creditos_df.dtypes.astype(str)
}).reset_index(drop=True)

estilo_tabla(tipos_creditos_post, titulo="Tipos de datos después de la corrección – Créditos")
# Out:
# <style type="text/css">
# #T_100e3 caption {
#   color: #2c3e50;
#   font-size: 16px;
#   font-weight: bold;
#   text-align: left;
#   margin-bottom: 10px;
# }
# #T_100e3 th {
#   background-color: #2c3e50;
#   color: white;
#   font-weight: bold;
#   border: 1px solid #ddd;
#   padding: 5px;
# }
# #T_100e3 td {
#   border: 1px solid #ddd;
#   padding: 5px;
# }
# #T_100e3_row0_col0, #T_100e3_row0_col1, #T_100e3_row1_col0, #T_100e3_row1_col1, #T_100e3_row2_col0, #T_100e3_row2_col1, #T_100e3_row3_col0, #T_100e3_row3_col1, #T_100e3_row4_col0, #T_100e3_row4_col1, #T_100e3_row5_col0, #T_100e3_row5_col1, #T_100e3_row6_col0, #T_100e3_row6_col1, #T_100e3_row7_col0, #T_100e3_row7_col1, #T_100e3_row8_col0, #T_100e3_row8_col1, #T_100e3_row9_col0, #T_100e3_row9_col1, #T_100e3_row10_col0, #T_100e3_row10_col1, #T_100e3_row11_col0, #T_100e3_row11_col1, #T_100e3_row12_col0, #T_100e3_row12_col1, #T_100e3_row13_col0, #T_100e3_row13_col1, #T_100e3_row14_col0, #T_100e3_row14_col1, #T_100e3_row15_col0, #T_100e3_row15_col1, #T_100e3_row16_col0, #T_100e3_row16_col1, #T_100e3_row17_col0, #T_100e3_row17_col1, #T_100e3_row18_col0, #T_100e3_row18_col1, #T_100e3_row19_col0, #T_100e3_row19_col1, #T_100e3_row20_col0, #T_100e3_row20_col1, #T_100e3_row21_col0, #T_100e3_row21_col1, #T_100e3_row22_col0, #T_100e3_row22_col1, #T_100e3_row23_col0, #T_100e3_row23_col1, #T_100e3_row24_col0, #T_100e3_row24_col1, #T_100e3_row25_col0, #T_100e3_row25_col1, #T_100e3_row26_col0, #T_100e3_row26_col1, #T_100e3_row27_col0, #T_100e3_row27_col1, #T_100e3_row28_col0, #T_100e3_row28_col1, #T_100e3_row29_col0, #T_100e3_row29_col1 {
#   text-align: left;
# }
# </style>
# <table id="T_100e3" class="dataframe">
#   <caption>Tipos de datos después de la corrección – Créditos</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_100e3_level0_col0" class="col_heading level0 col0" >columna</th>
#       <th id="T_100e3_level0_col1" class="col_heading level0 col1" >tipo_dato</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_100e3_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_100e3_row0_col0" class="data row0 col0" >Cliente</td>
#       <td id="T_100e3_row0_col1" class="data row0 col1" >Int64</td>
#     </tr>
#     <tr>
#       <th id="T_100e3_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_100e3_row1_col0" class="data row1 col0" >Tipo_identificacion</td>
#       <td id="T_100e3_row1_col1" class="data row1 col1" >category</td>
#     </tr>
#     <tr>
#       <th id="T_100e3_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_100e3_row2_col0" class="data row2 col0" >ID_Estudiante</td>
#       <td id="T_100e3_row2_col1" class="data row2 col1" >category</td>
#     </tr>
#     <tr>
#       <th id="T_100e3_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_100e3_row3_col0" class="data row3 col0" >Credito</td>
#       <td id="T_100e3_row3_col1" class="data row3 col1" >Int64</td>
#     </tr>
#     <tr>
#       <th id="T_100e3_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_100e3_row4_col0" class="data row4 col0" >Contar</td>
#       <td id="T_100e3_row4_col1" class="data row4 col1" >Int64</td>
#     </tr>
#     <tr>
#       <th id="T_100e3_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_100e3_row5_col0" class="data row5 col0" >Linea_credito</td>
#       <td id="T_100e3_row5_col1" class="data row5 col1" >category</td>
#     </tr>
#     <tr>
#       <th id="T_100e3_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_100e3_row6_col0" class="data row6 col0" >Descripcion_linea_credito</td>
#       <td id="T_100e3_row6_col1" class="data row6 col1" >category</td>
#     </tr>
#     <tr>
#       <th id="T_100e3_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_100e3_row7_col0" class="data row7 col0" >Nota_debito</td>
#       <td id="T_100e3_row7_col1" class="data row7 col1" >Int64</td>
#     </tr>
#     <tr>
#       <th id="T_100e3_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_100e3_row8_col0" class="data row8 col0" >Concepto_nota_debito</td>
#       <td id="T_100e3_row8_col1" class="data row8 col1" >Int64</td>
#     </tr>
#     <tr>
#       <th id="T_100e3_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_100e3_row9_col0" class="data row9 col0" >Nombre_concepto</td>
#       <td id="T_100e3_row9_col1" class="data row9 col1" >category</td>
#     </tr>
#     <tr>
#       <th id="T_100e3_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_100e3_row10_col0" class="data row10 col0" >Causa_nota_debito</td>
#       <td id="T_100e3_row10_col1" class="data row10 col1" >Int64</td>
#     </tr>
#     <tr>
#       <th id="T_100e3_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_100e3_row11_col0" class="data row11 col0" >Nombre_causa_nota</td>
#       <td id="T_100e3_row11_col1" class="data row11 col1" >category</td>
#     </tr>
#     <tr>
#       <th id="T_100e3_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_100e3_row12_col0" class="data row12 col0" >Valor_nota_debito</td>
#       <td id="T_100e3_row12_col1" class="data row12 col1" >float64</td>
#     </tr>
#     <tr>
#       <th id="T_100e3_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_100e3_row13_col0" class="data row13 col0" >Valor_pagado_nota_debito</td>
#       <td id="T_100e3_row13_col1" class="data row13 col1" >float64</td>
#     </tr>
#     <tr>
#       <th id="T_100e3_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_100e3_row14_col0" class="data row14 col0" >Fecha_pago_nota_debito</td>
#       <td id="T_100e3_row14_col1" class="data row14 col1" >datetime64[ns]</td>
#     </tr>
#     <tr>
#       <th id="T_100e3_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_100e3_row15_col0" class="data row15 col0" >Saldo_nota_debito</td>
#       <td id="T_100e3_row15_col1" class="data row15 col1" >float64</td>
#     </tr>
#     <tr>
#       <th id="T_100e3_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_100e3_row16_col0" class="data row16 col0" >% Recaudo</td>
#       <td id="T_100e3_row16_col1" class="data row16 col1" >float64</td>
#     </tr>
#     <tr>
#       <th id="T_100e3_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_100e3_row17_col0" class="data row17 col0" >Fecha_vencimiento_ndb</td>
#       <td id="T_100e3_row17_col1" class="data row17 col1" >datetime64[ns]</td>
#     </tr>
#     <tr>
#       <th id="T_100e3_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_100e3_row18_col0" class="data row18 col0" >Periodo_facturacion</td>
#       <td id="T_100e3_row18_col1" class="data row18 col1" >category</td>
#     </tr>
#     <tr>
#       <th id="T_100e3_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_100e3_row19_col0" class="data row19 col0" >Mes_facturacion</td>
#       <td id="T_100e3_row19_col1" class="data row19 col1" >category</td>
#     </tr>
#     <tr>
#       <th id="T_100e3_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_100e3_row20_col0" class="data row20 col0" >Periodo_academico</td>
#       <td id="T_100e3_row20_col1" class="data row20 col1" >category</td>
#     </tr>
#     <tr>
#       <th id="T_100e3_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_100e3_row21_col0" class="data row21 col0" >Documento</td>
#       <td id="T_100e3_row21_col1" class="data row21 col1" >string</td>
#     </tr>
#     <tr>
#       <th id="T_100e3_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_100e3_row22_col0" class="data row22 col0" >Estado</td>
#       <td id="T_100e3_row22_col1" class="data row22 col1" >category</td>
#     </tr>
#     <tr>
#       <th id="T_100e3_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_100e3_row23_col0" class="data row23 col0" >Estado_describe</td>
#       <td id="T_100e3_row23_col1" class="data row23 col1" >category</td>
#     </tr>
#     <tr>
#       <th id="T_100e3_level0_row24" class="row_heading level0 row24" >24</th>
#       <td id="T_100e3_row

# %%
# Corrección de tipos de datos en cartera_df

# Limpieza ligera de nombres de columnas (quita espacios al inicio/fin)
cartera_df.columns = cartera_df.columns.str.strip()

# Conversión de columnas de fecha a datetime
cols_fecha_cartera = [
    "FECHA CANCELACIÓN",
    "FECHA LIQUIDACIÓN INTERÉS",
    "INICIO DIFERIDO",
    "FECHA",
    "FECHA VENCE",
    "FECHA DOCUMENTO",
    "FECHA VENCIMIENTO",
]

for col in cols_fecha_cartera:
    if col in cartera_df.columns:
        cartera_df[col] = pd.to_datetime(
            cartera_df[col],
            errors="coerce",
            dayfirst=True
        )

# Conversión de columnas numéricas ENTERAS (códigos, contadores, etc.)
cols_int_cartera = [
    "ORGANIZACIÓN ORIGEN",
    "NÚMERO ORIGEN",
    "CLASIFICADOR",
    "REFERENCIA",
    "GRUPO",
    "LIQUIDACIÓN ORDEN",
    "CRÉDITO",
    "FUENTE FUNCIÓN",
    "CLIENTE",
    "DÍAS",
    "# REG",
    "EDAD CARTERA",
    "NÚMERO CRÉDITO",
    "ORGANIZACIÓN",
    "TIPO CLIENTE",
    "VALOR DESCUENTO",
    "FONDO",
    "ORGANIZACIÓN CENTRO",
    "CENTRO COSTO",
    "MESES DIFERIDO",
]

for col in cols_int_cartera:
    if col in cartera_df.columns:
        cartera_df[col] = pd.to_numeric(cartera_df[col], errors="coerce").astype("Int64")

# Conversión de columnas numéricas CONTINUAS (montos, tasas, saldos)
cols_float_cartera = [
    "CUOTA",
    "TASA INTERÉS MORA",
    "CONCEPTO NOTA",
    "CAUSA NOTA",
    "SALDO",
    "VALOR BRUTO",
    "VALOR TOTAL",
    "VALOR AFECTADO",
    "VALOR DOCUMENTO",
]

for col in cols_float_cartera:
    if col in cartera_df.columns:
        cartera_df[col] = pd.to_numeric(cartera_df[col], errors="coerce")

# Conversión de columnas categóricas (texto con categorías)

cols_cat_cartera = [
    "DOCUMENTO ORIGEN",
    "NOMBRE REFERENCIA",
    "NOMBRE CONCEPTO CRÉDITO",
    "CONCEPTO CRÉDITO",
    "NOMBRE CAUSA NOTA",
    "CONTROL SALDO",
    "NOMBRE CONCEPTO",
    "NOMBRE PERIODO",
    "NOMBRE FUENTE FUNCIÓN",
    "TIPO ID",
    "ID_Estudiante",
    "NOMBRE EDAD",
    "CONCEPTO",
    "NOMBRE DOCUMENTO",
    "RANGO",
    "NOMBRE TIPO CLIENTE",
    "TIPO CARTERA",
    "TIPO CARTERA 2",
    "ACTIVA / INACTIVA",
    "TIPO DOCUMENTO",
    "NOMBRE TIPO DOCUMENTO",
    "DOCUMENTO",
    "GENERA MORA",
    "DESCRIPCIÓN",
    "NOMBRE CENTRO COSTO",
    "NOMBRE FONDO",
    "ESTADO",
]

for col in cols_cat_cartera:
    if col in cartera_df.columns:
        cartera_df[col] = cartera_df[col].astype("category")

print("Corrección de tipos completada para cartera_df.")
# Out:
# Corrección de tipos completada para cartera_df.

# %%
tipos_cartera_post = pd.DataFrame({
    "columna": cartera_df.columns,
    "tipo_dato": cartera_df.dtypes.astype(str)
}).reset_index(drop=True)

estilo_tabla(tipos_cartera_post, titulo="Tipos de datos después de la corrección – Cartera Depurada")
# Out:
# <style type="text/css">
# #T_e84ea caption {
#   color: #2c3e50;
#   font-size: 16px;
#   font-weight: bold;
#   text-align: left;
#   margin-bottom: 10px;
# }
# #T_e84ea th {
#   background-color: #2c3e50;
#   color: white;
#   font-weight: bold;
#   border: 1px solid #ddd;
#   padding: 5px;
# }
# #T_e84ea td {
#   border: 1px solid #ddd;
#   padding: 5px;
# }
# #T_e84ea_row0_col0, #T_e84ea_row0_col1, #T_e84ea_row1_col0, #T_e84ea_row1_col1, #T_e84ea_row2_col0, #T_e84ea_row2_col1, #T_e84ea_row3_col0, #T_e84ea_row3_col1, #T_e84ea_row4_col0, #T_e84ea_row4_col1, #T_e84ea_row5_col0, #T_e84ea_row5_col1, #T_e84ea_row6_col0, #T_e84ea_row6_col1, #T_e84ea_row7_col0, #T_e84ea_row7_col1, #T_e84ea_row8_col0, #T_e84ea_row8_col1, #T_e84ea_row9_col0, #T_e84ea_row9_col1, #T_e84ea_row10_col0, #T_e84ea_row10_col1, #T_e84ea_row11_col0, #T_e84ea_row11_col1, #T_e84ea_row12_col0, #T_e84ea_row12_col1, #T_e84ea_row13_col0, #T_e84ea_row13_col1, #T_e84ea_row14_col0, #T_e84ea_row14_col1, #T_e84ea_row15_col0, #T_e84ea_row15_col1, #T_e84ea_row16_col0, #T_e84ea_row16_col1, #T_e84ea_row17_col0, #T_e84ea_row17_col1, #T_e84ea_row18_col0, #T_e84ea_row18_col1, #T_e84ea_row19_col0, #T_e84ea_row19_col1, #T_e84ea_row20_col0, #T_e84ea_row20_col1, #T_e84ea_row21_col0, #T_e84ea_row21_col1, #T_e84ea_row22_col0, #T_e84ea_row22_col1, #T_e84ea_row23_col0, #T_e84ea_row23_col1, #T_e84ea_row24_col0, #T_e84ea_row24_col1, #T_e84ea_row25_col0, #T_e84ea_row25_col1, #T_e84ea_row26_col0, #T_e84ea_row26_col1, #T_e84ea_row27_col0, #T_e84ea_row27_col1, #T_e84ea_row28_col0, #T_e84ea_row28_col1, #T_e84ea_row29_col0, #T_e84ea_row29_col1, #T_e84ea_row30_col0, #T_e84ea_row30_col1, #T_e84ea_row31_col0, #T_e84ea_row31_col1, #T_e84ea_row32_col0, #T_e84ea_row32_col1, #T_e84ea_row33_col0, #T_e84ea_row33_col1, #T_e84ea_row34_col0, #T_e84ea_row34_col1, #T_e84ea_row35_col0, #T_e84ea_row35_col1, #T_e84ea_row36_col0, #T_e84ea_row36_col1, #T_e84ea_row37_col0, #T_e84ea_row37_col1, #T_e84ea_row38_col0, #T_e84ea_row38_col1, #T_e84ea_row39_col0, #T_e84ea_row39_col1, #T_e84ea_row40_col0, #T_e84ea_row40_col1, #T_e84ea_row41_col0, #T_e84ea_row41_col1, #T_e84ea_row42_col0, #T_e84ea_row42_col1, #T_e84ea_row43_col0, #T_e84ea_row43_col1, #T_e84ea_row44_col0, #T_e84ea_row44_col1, #T_e84ea_row45_col0, #T_e84ea_row45_col1, #T_e84ea_row46_col0, #T_e84ea_row46_col1, #T_e84ea_row47_col0, #T_e84ea_row47_col1, #T_e84ea_row48_col0, #T_e84ea_row48_col1, #T_e84ea_row49_col0, #T_e84ea_row49_col1, #T_e84ea_row50_col0, #T_e84ea_row50_col1, #T_e84ea_row51_col0, #T_e84ea_row51_col1, #T_e84ea_row52_col0, #T_e84ea_row52_col1, #T_e84ea_row53_col0, #T_e84ea_row53_col1, #T_e84ea_row54_col0, #T_e84ea_row54_col1, #T_e84ea_row55_col0, #T_e84ea_row55_col1, #T_e84ea_row56_col0, #T_e84ea_row56_col1, #T_e84ea_row57_col0, #T_e84ea_row57_col1, #T_e84ea_row58_col0, #T_e84ea_row58_col1, #T_e84ea_row59_col0, #T_e84ea_row59_col1, #T_e84ea_row60_col0, #T_e84ea_row60_col1, #T_e84ea_row61_col0, #T_e84ea_row61_col1, #T_e84ea_row62_col0, #T_e84ea_row62_col1, #T_e84ea_row63_col0, #T_e84ea_row63_col1, #T_e84ea_row64_col0, #T_e84ea_row64_col1, #T_e84ea_row65_col0, #T_e84ea_row65_col1 {
#   text-align: left;
# }
# </style>
# <table id="T_e84ea" class="dataframe">
#   <caption>Tipos de datos después de la corrección – Cartera Depurada</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e84ea_level0_col0" class="col_heading level0 col0" >columna</th>
#       <th id="T_e84ea_level0_col1" class="col_heading level0 col1" >tipo_dato</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e84ea_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e84ea_row0_col0" class="data row0 col0" >CLIENTE</td>
#       <td id="T_e84ea_row0_col1" class="data row0 col1" >Int64</td>
#     </tr>
#     <tr>
#       <th id="T_e84ea_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_e84ea_row1_col0" class="data row1 col0" >TIPO ID</td>
#       <td id="T_e84ea_row1_col1" class="data row1 col1" >category</td>
#     </tr>
#     <tr>
#       <th id="T_e84ea_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_e84ea_row2_col0" class="data row2 col0" >ID_Estudiante</td>
#       <td id="T_e84ea_row2_col1" class="data row2 col1" >category</td>
#     </tr>
#     <tr>
#       <th id="T_e84ea_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_e84ea_row3_col0" class="data row3 col0" ># REG</td>
#       <td id="T_e84ea_row3_col1" class="data row3 col1" >Int64</td>
#     </tr>
#     <tr>
#       <th id="T_e84ea_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_e84ea_row4_col0" class="data row4 col0" >EDAD CARTERA</td>
#       <td id="T_e84ea_row4_col1" class="data row4 col1" >Int64</td>
#     </tr>
#     <tr>
#       <th id="T_e84ea_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_e84ea_row5_col0" class="data row5 col0" >NOMBRE EDAD</td>
#       <td id="T_e84ea_row5_col1" class="data row5 col1" >category</td>
#     </tr>
#     <tr>
#       <th id="T_e84ea_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_e84ea_row6_col0" class="data row6 col0" >DÍAS</td>
#       <td id="T_e84ea_row6_col1" class="data row6 col1" >Int64</td>
#     </tr>
#     <tr>
#       <th id="T_e84ea_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_e84ea_row7_col0" class="data row7 col0" >RANGO</td>
#       <td id="T_e84ea_row7_col1" class="data row7 col1" >category</td>
#     </tr>
#     <tr>
#       <th id="T_e84ea_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_e84ea_row8_col0" class="data row8 col0" >SALDO</td>
#       <td id="T_e84ea_row8_col1" class="data row8 col1" >float64</td>
#     </tr>
#     <tr>
#       <th id="T_e84ea_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_e84ea_row9_col0" class="data row9 col0" >ORGANIZACIÓN</td>
#       <td id="T_e84ea_row9_col1" class="data row9 col1" >Int64</td>
#     </tr>
#     <tr>
#       <th id="T_e84ea_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_e84ea_row10_col0" class="data row10 col0" >TIPO CLIENTE</td>
#       <td id="T_e84ea_row10_col1" class="data row10 col1" >Int64</td>
#     </tr>
#     <tr>
#       <th id="T_e84ea_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_e84ea_row11_col0" class="data row11 col0" >NOMBRE TIPO CLIENTE</td>
#       <td id="T_e84ea_row11_col1" class="data row11 col1" >category</td>
#     </tr>
#     <tr>
#       <th id="T_e84ea_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_e84ea_row12_col0" class="data row12 col0" >TIPO CARTERA</td>
#       <td id="T_e84ea_row12_col1" class="data row12 col1" >category</td>
#     </tr>
#     <tr>
#       <th id="T_e84ea_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_e84ea_row13_col0" class="data row13 col0" >TIPO CARTERA 2</td>
#       <td id="T_e84ea_row13_col1" class="data row13 col1" >category</td>
#     </tr>
#     <tr>
#       <th id="T_e84ea_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_e84ea_row14_col0" class="data row14 col0" >ACTIVA / INACTIVA</td>
#       <td id="T_e84ea_row14_col1" class="data row14 col1" >category</td>
#     </tr>
#     <tr>
#       <th id="T_e84ea_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_e84ea_row15_col0" class="data row15 col0" >TIPO DOCUMENTO</td>
#       <td id="T_e84ea_row15_col1" class="data row15 col1" >category</td>
#     </tr>
#     <tr>
#       <th id="T_e84ea_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_e84ea_row16_col0" class="data row16 col0" >NOMBRE TIPO DOCUMENTO</td>
#       <td id="T_e84ea_row16_col1" class="data row16 col1" >category</td>
#     </tr>
#     <tr>
#       <th id="T_e84ea_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_e84ea_row17_col0" class="data row17 col0" >DOCUMENTO</td>
#       <td id="T_e84ea_row17_col1" class="data row17 col1" >category</td>
#     </tr>
#     <tr>
#       <th id="T_e84ea_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_e84ea_row18_col0" class="data row18 col0" >NOMBRE DOCUMENTO</td>

# %%
# Corrección de tipos de datos en pagares_df

# Limpieza ligera de nombres de columnas (quita espacios al inicio/fin)
pagares_df.columns = pagares_df.columns.str.strip()

# Conversión de columnas numéricas (Estrato)

cols_int_pagares = [
    "Estrato",
]

for col in cols_int_pagares:
    if col in pagares_df.columns:
        pagares_df[col] = pd.to_numeric(
            pagares_df[col],
            errors="coerce"
        ).astype("Int64")   # entero con soporte para NA

# Conversión de columnas categóricas (incluye IDs y variables socio-demo)

cols_categoricas_pagares = [
    "ID CRÉDITO",      # identificador del crédito
    "ID_CREDITO",      # por si viene sin tilde
    "ID_Estudiante",
    "Sexo",
    "Departamento",
    "Departament",     # por si viene truncado
    "Pais Nacimiento",
    "Pais_Nacimiento",
    "Primiparo",
    "Estado_est",
    "Graduado",
    "Cargo_codeudor",
]

for col in cols_categoricas_pagares:
    if col in pagares_df.columns:
        pagares_df[col] = pagares_df[col].astype("category")

print("Corrección de tipos completada para pagares_df.")
pagares_df.dtypes

info_pagares_tipos = pd.DataFrame({
    "columna": pagares_df.columns,
    "tipo_dato": pagares_df.dtypes.astype(str)
})

# Ordenar alfabéticamente para mejorar legibilidad (opcional)
info_pagares_tipos = info_pagares_tipos.sort_values("columna").reset_index(drop=True)

estilo_tabla(info_pagares_tipos, titulo="Tipos de datos después de la corrección — Info Pagares")
# Out:
# Corrección de tipos completada para pagares_df.
# <style type="text/css">
# #T_d5723 caption {
#   color: #2c3e50;
#   font-size: 16px;
#   font-weight: bold;
#   text-align: left;
#   margin-bottom: 10px;
# }
# #T_d5723 th {
#   background-color: #2c3e50;
#   color: white;
#   font-weight: bold;
#   border: 1px solid #ddd;
#   padding: 5px;
# }
# #T_d5723 td {
#   border: 1px solid #ddd;
#   padding: 5px;
# }
# #T_d5723_row0_col0, #T_d5723_row0_col1, #T_d5723_row1_col0, #T_d5723_row1_col1, #T_d5723_row2_col0, #T_d5723_row2_col1, #T_d5723_row3_col0, #T_d5723_row3_col1, #T_d5723_row4_col0, #T_d5723_row4_col1, #T_d5723_row5_col0, #T_d5723_row5_col1, #T_d5723_row6_col0, #T_d5723_row6_col1, #T_d5723_row7_col0, #T_d5723_row7_col1, #T_d5723_row8_col0, #T_d5723_row8_col1, #T_d5723_row9_col0, #T_d5723_row9_col1 {
#   text-align: left;
# }
# </style>
# <table id="T_d5723" class="dataframe">
#   <caption>Tipos de datos después de la corrección — Info Pagares</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d5723_level0_col0" class="col_heading level0 col0" >columna</th>
#       <th id="T_d5723_level0_col1" class="col_heading level0 col1" >tipo_dato</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d5723_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d5723_row0_col0" class="data row0 col0" >Cargo_codeudor</td>
#       <td id="T_d5723_row0_col1" class="data row0 col1" >category</td>
#     </tr>
#     <tr>
#       <th id="T_d5723_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_d5723_row1_col0" class="data row1 col0" >Departamento</td>
#       <td id="T_d5723_row1_col1" class="data row1 col1" >category</td>
#     </tr>
#     <tr>
#       <th id="T_d5723_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_d5723_row2_col0" class="data row2 col0" >Estado_est</td>
#       <td id="T_d5723_row2_col1" class="data row2 col1" >category</td>
#     </tr>
#     <tr>
#       <th id="T_d5723_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_d5723_row3_col0" class="data row3 col0" >Estrato</td>
#       <td id="T_d5723_row3_col1" class="data row3 col1" >Int64</td>
#     </tr>
#     <tr>
#       <th id="T_d5723_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_d5723_row4_col0" class="data row4 col0" >Graduado</td>
#       <td id="T_d5723_row4_col1" class="data row4 col1" >category</td>
#     </tr>
#     <tr>
#       <th id="T_d5723_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_d5723_row5_col0" class="data row5 col0" >ID CRÉDITO</td>
#       <td id="T_d5723_row5_col1" class="data row5 col1" >category</td>
#     </tr>
#     <tr>
#       <th id="T_d5723_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_d5723_row6_col0" class="data row6 col0" >ID_Estudiante</td>
#       <td id="T_d5723_row6_col1" class="data row6 col1" >category</td>
#     </tr>
#     <tr>
#       <th id="T_d5723_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_d5723_row7_col0" class="data row7 col0" >Pais Nacimiento</td>
#       <td id="T_d5723_row7_col1" class="data row7 col1" >category</td>
#     </tr>
#     <tr>
#       <th id="T_d5723_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_d5723_row8_col0" class="data row8 col0" >Primiparo</td>
#       <td id="T_d5723_row8_col1" class="data row8 col1" >category</td>
#     </tr>
#     <tr>
#       <th id="T_d5723_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_d5723_row9_col0" class="data row9 col0" >Sexo</td>
#       <td id="T_d5723_row9_col1" class="data row9 col1" >category</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Primero, cargamos y revisamos los datos para entender qué información trae cada columna. Luego, analizamos el tipo de dato de cada columna (si es número, texto, fecha, etc.) y corregimos aquellos que estaban mal asignados, asegurando que cada variable tenga el formato correcto.
#
# Por ejemplo, convertimos las fechas que estaban como texto a formato de fecha, los montos y cantidades a números, y las columnas con nombres o categorías a un formato especial que permite manejarlas fácilmente. Esto es fundamental para que cualquier análisis, gráfica o modelo que hagamos después sea confiable y funcione correctamente. Así, dejamos los datos listos y organizados para seguir con el análisis exploratorio y la resolución del problema de negocio.

# %% [markdown]
# Preparación del EDA:

# %%
# Preconfiguración visual para EDA

import matplotlib.pyplot as plt
import seaborn as sns

plt.style.use("seaborn-v0_8-whitegrid")
plt.rcParams['figure.figsize'] = (10, 5)
sns.set_palette("deep")

# %% [markdown]
# Identificación de variables categóricas y numéricas:

# %%
# Identificación automática de variables

def identificar_tipos(df):
    numericas = df.select_dtypes(include=["int64", "Int64", "float64"]).columns.tolist()
    fechas    = df.select_dtypes(include=["datetime64[ns]"]).columns.tolist()
    categoricas = df.select_dtypes(include=["category", "object", "string"]).columns.tolist()
    return numericas, fechas, categoricas

# Créditos
num_creditos, fecha_creditos, cat_creditos = identificar_tipos(creditos_df)

# Cartera depurada
num_cartera, fecha_cartera, cat_cartera = identificar_tipos(cartera_df)

# Info Pagares
num_pagares, fecha_pagares, cat_pagares = identificar_tipos(pagares_df)

# Resumen en una sola tabla
resumen_tipos = pd.DataFrame({
    "Variables Numéricas Créditos":   [len(num_creditos)],
    "Variables Categóricas Créditos": [len(cat_creditos)],
    "Variables Fecha Créditos":       [len(fecha_creditos)],
    "Variables Numéricas Cartera":    [len(num_cartera)],
    "Variables Categóricas Cartera":  [len(cat_cartera)],
    "Variables Fecha Cartera":        [len(fecha_cartera)],
    "Variables Numéricas Pagares":    [len(num_pagares)],
    "Variables Categóricas Pagares":  [len(cat_pagares)],
    "Variables Fecha Pagares":        [len(fecha_pagares)],
})

estilo_tabla(resumen_tipos, titulo="Resumen inicial de tipos por dataset")
# Out:
# <style type="text/css">
# #T_95437 caption {
#   color: #2c3e50;
#   font-size: 16px;
#   font-weight: bold;
#   text-align: left;
#   margin-bottom: 10px;
# }
# #T_95437 th {
#   background-color: #2c3e50;
#   color: white;
#   font-weight: bold;
#   border: 1px solid #ddd;
#   padding: 5px;
# }
# #T_95437 td {
#   border: 1px solid #ddd;
#   padding: 5px;
# }
# #T_95437_row0_col0, #T_95437_row0_col1, #T_95437_row0_col2, #T_95437_row0_col3, #T_95437_row0_col4, #T_95437_row0_col5, #T_95437_row0_col6, #T_95437_row0_col7, #T_95437_row0_col8 {
#   text-align: left;
# }
# </style>
# <table id="T_95437" class="dataframe">
#   <caption>Resumen inicial de tipos por dataset</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_95437_level0_col0" class="col_heading level0 col0" >Variables Numéricas Créditos</th>
#       <th id="T_95437_level0_col1" class="col_heading level0 col1" >Variables Categóricas Créditos</th>
#       <th id="T_95437_level0_col2" class="col_heading level0 col2" >Variables Fecha Créditos</th>
#       <th id="T_95437_level0_col3" class="col_heading level0 col3" >Variables Numéricas Cartera</th>
#       <th id="T_95437_level0_col4" class="col_heading level0 col4" >Variables Categóricas Cartera</th>
#       <th id="T_95437_level0_col5" class="col_heading level0 col5" >Variables Fecha Cartera</th>
#       <th id="T_95437_level0_col6" class="col_heading level0 col6" >Variables Numéricas Pagares</th>
#       <th id="T_95437_level0_col7" class="col_heading level0 col7" >Variables Categóricas Pagares</th>
#       <th id="T_95437_level0_col8" class="col_heading level0 col8" >Variables Fecha Pagares</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_95437_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_95437_row0_col0" class="data row0 col0" >12</td>
#       <td id="T_95437_row0_col1" class="data row0 col1" >14</td>
#       <td id="T_95437_row0_col2" class="data row0 col2" >4</td>
#       <td id="T_95437_row0_col3" class="data row0 col3" >30</td>
#       <td id="T_95437_row0_col4" class="data row0 col4" >29</td>
#       <td id="T_95437_row0_col5" class="data row0 col5" >7</td>
#       <td id="T_95437_row0_col6" class="data row0 col6" >1</td>
#       <td id="T_95437_row0_col7" class="data row0 col7" >9</td>
#       <td id="T_95437_row0_col8" class="data row0 col8" >0</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Estadísticas descriptivas:

# %%
# Estadísticas Descriptivas - Créditos

# 1. Excluir Cliente
num_creditos_filtrado = [col for col in num_creditos if col != "Cliente"]

# 2. Estadísticos base
desc_creditos = creditos_df[num_creditos_filtrado].describe().T

# 3. Mediana y rango
desc_creditos["median"] = creditos_df[num_creditos_filtrado].median()
desc_creditos["range"] = desc_creditos["max"] - desc_creditos["min"]

# 4. Reordenar columnas
desc_creditos = desc_creditos[
    ["count", "mean", "median", "std", "min", "25%", "50%", "75%", "max", "range"]
]

# 5. Función de estilo
def estilo_estadisticas(df):
    return (
        df.style
        .set_caption("📊 Estadísticas Descriptivas – Créditos")
        .format("{:,.0f}", na_rep="-")  # SIN decimales + separador de miles
        .set_table_styles([
            # Estilo del título
            {"selector": "caption",
             "props": [("font-size", "18px"),
                       ("font-weight", "bold"),
                       ("color", "#2c3e50"),
                       ("text-align", "left"),
                       ("margin", "10px 0")]},

            # Encabezados
            {"selector": "th",
             "props": [("background-color", "#1f2d3d"),
                       ("color", "white"),
                       ("font-weight", "bold"),
                       ("padding", "8px"),
                       ("border-bottom", "2px solid #34495e")]}
        ])
        .set_properties(**{  # Estilo celdas
            "text-align": "right",
            "padding": "6px",
            "border": "1px solid #e0e0e0",
            "font-size": "13px"
        })
        .apply(lambda x: ["background-color: #f9f9f9" if i % 2 == 0 else ""
                          for i in range(len(x))], axis=0)  # filas alternadas
    )

# Mostrar tabla con estilo
estilo_estadisticas(desc_creditos)
# Out:
# <style type="text/css">
# #T_493ba caption {
#   font-size: 18px;
#   font-weight: bold;
#   color: #2c3e50;
#   text-align: left;
#   margin: 10px 0;
# }
# #T_493ba th {
#   background-color: #1f2d3d;
#   color: white;
#   font-weight: bold;
#   padding: 8px;
#   border-bottom: 2px solid #34495e;
# }
# #T_493ba_row0_col0, #T_493ba_row0_col1, #T_493ba_row0_col2, #T_493ba_row0_col3, #T_493ba_row0_col4, #T_493ba_row0_col5, #T_493ba_row0_col6, #T_493ba_row0_col7, #T_493ba_row0_col8, #T_493ba_row0_col9, #T_493ba_row2_col0, #T_493ba_row2_col1, #T_493ba_row2_col2, #T_493ba_row2_col3, #T_493ba_row2_col4, #T_493ba_row2_col5, #T_493ba_row2_col6, #T_493ba_row2_col7, #T_493ba_row2_col8, #T_493ba_row2_col9, #T_493ba_row4_col0, #T_493ba_row4_col1, #T_493ba_row4_col2, #T_493ba_row4_col3, #T_493ba_row4_col4, #T_493ba_row4_col5, #T_493ba_row4_col6, #T_493ba_row4_col7, #T_493ba_row4_col8, #T_493ba_row4_col9, #T_493ba_row6_col0, #T_493ba_row6_col1, #T_493ba_row6_col2, #T_493ba_row6_col3, #T_493ba_row6_col4, #T_493ba_row6_col5, #T_493ba_row6_col6, #T_493ba_row6_col7, #T_493ba_row6_col8, #T_493ba_row6_col9, #T_493ba_row8_col0, #T_493ba_row8_col1, #T_493ba_row8_col2, #T_493ba_row8_col3, #T_493ba_row8_col4, #T_493ba_row8_col5, #T_493ba_row8_col6, #T_493ba_row8_col7, #T_493ba_row8_col8, #T_493ba_row8_col9, #T_493ba_row10_col0, #T_493ba_row10_col1, #T_493ba_row10_col2, #T_493ba_row10_col3, #T_493ba_row10_col4, #T_493ba_row10_col5, #T_493ba_row10_col6, #T_493ba_row10_col7, #T_493ba_row10_col8, #T_493ba_row10_col9 {
#   text-align: right;
#   padding: 6px;
#   border: 1px solid #e0e0e0;
#   font-size: 13px;
#   background-color: #f9f9f9;
# }
# #T_493ba_row1_col0, #T_493ba_row1_col1, #T_493ba_row1_col2, #T_493ba_row1_col3, #T_493ba_row1_col4, #T_493ba_row1_col5, #T_493ba_row1_col6, #T_493ba_row1_col7, #T_493ba_row1_col8, #T_493ba_row1_col9, #T_493ba_row3_col0, #T_493ba_row3_col1, #T_493ba_row3_col2, #T_493ba_row3_col3, #T_493ba_row3_col4, #T_493ba_row3_col5, #T_493ba_row3_col6, #T_493ba_row3_col7, #T_493ba_row3_col8, #T_493ba_row3_col9, #T_493ba_row5_col0, #T_493ba_row5_col1, #T_493ba_row5_col2, #T_493ba_row5_col3, #T_493ba_row5_col4, #T_493ba_row5_col5, #T_493ba_row5_col6, #T_493ba_row5_col7, #T_493ba_row5_col8, #T_493ba_row5_col9, #T_493ba_row7_col0, #T_493ba_row7_col1, #T_493ba_row7_col2, #T_493ba_row7_col3, #T_493ba_row7_col4, #T_493ba_row7_col5, #T_493ba_row7_col6, #T_493ba_row7_col7, #T_493ba_row7_col8, #T_493ba_row7_col9, #T_493ba_row9_col0, #T_493ba_row9_col1, #T_493ba_row9_col2, #T_493ba_row9_col3, #T_493ba_row9_col4, #T_493ba_row9_col5, #T_493ba_row9_col6, #T_493ba_row9_col7, #T_493ba_row9_col8, #T_493ba_row9_col9 {
#   text-align: right;
#   padding: 6px;
#   border: 1px solid #e0e0e0;
#   font-size: 13px;
# }
# </style>
# <table id="T_493ba" class="dataframe">
#   <caption>📊 Estadísticas Descriptivas – Créditos</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_493ba_level0_col0" class="col_heading level0 col0" >count</th>
#       <th id="T_493ba_level0_col1" class="col_heading level0 col1" >mean</th>
#       <th id="T_493ba_level0_col2" class="col_heading level0 col2" >median</th>
#       <th id="T_493ba_level0_col3" class="col_heading level0 col3" >std</th>
#       <th id="T_493ba_level0_col4" class="col_heading level0 col4" >min</th>
#       <th id="T_493ba_level0_col5" class="col_heading level0 col5" >25%</th>
#       <th id="T_493ba_level0_col6" class="col_heading level0 col6" >50%</th>
#       <th id="T_493ba_level0_col7" class="col_heading level0 col7" >75%</th>
#       <th id="T_493ba_level0_col8" class="col_heading level0 col8" >max</th>
#       <th id="T_493ba_level0_col9" class="col_heading level0 col9" >range</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_493ba_level0_row0" class="row_heading level0 row0" >Credito</th>
#       <td id="T_493ba_row0_col0" class="data row0 col0" >405,829</td>
#       <td id="T_493ba_row0_col1" class="data row0 col1" >84,009</td>
#       <td id="T_493ba_row0_col2" class="data row0 col2" >71,918</td>
#       <td id="T_493ba_row0_col3" class="data row0 col3" >58,036</td>
#       <td id="T_493ba_row0_col4" class="data row0 col4" >1</td>
#       <td id="T_493ba_row0_col5" class="data row0 col5" >33,210</td>
#       <td id="T_493ba_row0_col6" class="data row0 col6" >71,918</td>
#       <td id="T_493ba_row0_col7" class="data row0 col7" >135,086</td>
#       <td id="T_493ba_row0_col8" class="data row0 col8" >199,727</td>
#       <td id="T_493ba_row0_col9" class="data row0 col9" >199,726</td>
#     </tr>
#     <tr>
#       <th id="T_493ba_level0_row1" class="row_heading level0 row1" >Contar</th>
#       <td id="T_493ba_row1_col0" class="data row1 col0" >405,829</td>
#       <td id="T_493ba_row1_col1" class="data row1 col1" >0</td>
#       <td id="T_493ba_row1_col2" class="data row1 col2" >0</td>
#       <td id="T_493ba_row1_col3" class="data row1 col3" >0</td>
#       <td id="T_493ba_row1_col4" class="data row1 col4" >0</td>
#       <td id="T_493ba_row1_col5" class="data row1 col5" >0</td>
#       <td id="T_493ba_row1_col6" class="data row1 col6" >0</td>
#       <td id="T_493ba_row1_col7" class="data row1 col7" >1</td>
#       <td id="T_493ba_row1_col8" class="data row1 col8" >1</td>
#       <td id="T_493ba_row1_col9" class="data row1 col9" >1</td>
#     </tr>
#     <tr>
#       <th id="T_493ba_level0_row2" class="row_heading level0 row2" >Nota_debito</th>
#       <td id="T_493ba_row2_col0" class="data row2 col0" >405,829</td>
#       <td id="T_493ba_row2_col1" class="data row2 col1" >1,483,930</td>
#       <td id="T_493ba_row2_col2" class="data row2 col2" >1,464,173</td>
#       <td id="T_493ba_row2_col3" class="data row2 col3" >861,110</td>
#       <td id="T_493ba_row2_col4" class="data row2 col4" >10,036</td>
#       <td id="T_493ba_row2_col5" class="data row2 col5" >718,773</td>
#       <td id="T_493ba_row2_col6" class="data row2 col6" >1,464,173</td>
#       <td id="T_493ba_row2_col7" class="data row2 col7" >2,220,639</td>
#       <td id="T_493ba_row2_col8" class="data row2 col8" >2,983,837</td>
#       <td id="T_493ba_row2_col9" class="data row2 col9" >2,973,801</td>
#     </tr>
#     <tr>
#       <th id="T_493ba_level0_row3" class="row_heading level0 row3" >Concepto_nota_debito</th>
#       <td id="T_493ba_row3_col0" class="data row3 col0" >405,829</td>
#       <td id="T_493ba_row3_col1" class="data row3 col1" >134</td>
#       <td id="T_493ba_row3_col2" class="data row3 col2" >99</td>
#       <td id="T_493ba_row3_col3" class="data row3 col3" >100</td>
#       <td id="T_493ba_row3_col4" class="data row3 col4" >99</td>
#       <td id="T_493ba_row3_col5" class="data row3 col5" >99</td>
#       <td id="T_493ba_row3_col6" class="data row3 col6" >99</td>
#       <td id="T_493ba_row3_col7" class="data row3 col7" >99</td>
#       <td id="T_493ba_row3_col8" class="data row3 col8" >515</td>
#       <td id="T_493ba_row3_col9" class="data row3 col9" >416</td>
#     </tr>
#     <tr>
#       <th id="T_493ba_level0_row4" class="row_heading level0 row4" >Causa_nota_debito</th>
#       <td id="T_493ba_row4_col0" class="data row4 col0" >405,829</td>
#       <td id="T_493ba_row4_col1" class="data row4 col1" >281</td>
#       <td id="T_493ba_row4_col2" class="data row4 col2" >204</td>
#       <td id="T_493ba_row4_col3" class="data row4 col3" >192</td>
#       <td id="T_493ba_row4_col4" class="data row4 col4" >172</td>
#       <td id="T_493ba_row4_col5" class="data row4 col5" >204</td>
#       <td id="T_493ba_row4_col6" class="data row4 col6" >204</td>
#       <td id="T_493ba_row4_col7" class="data row4 col7" >204</td>
#       <td id="T_493ba_row4_col8" class="data row4 col8" >870</td>
#       <td id="T_493ba_row4_col9" class="data row4 col9" >698</td>
#     </tr>
#     <tr>
#       <th id="T_493ba_level0_row5" class="row_heading level0 row5" >Valor_nota_debito</th>
#       <td id="T_493ba_row5_col0" class="data row5 col0" >405,829</td>
#       <td id="T_493ba_row5_col1" class="data row5 col1" >777,171</td>
#       <td id="T_493ba_row5_col2" class="data row5 col2" >537,500</td>
#       <td id="T_493ba_row5_col3" class="data row5 col3" >988,349</td>
#       <td id="T_493ba_row5_col4" class="data row5 col4"

# %% [markdown]
# **Análisis de Estadísticas Descriptivas - Dataset Créditos**
#
# Al revisar las estadísticas de las variables numéricas del dataset de créditos, podemos identificar varios patrones interesantes sobre el comportamiento de los créditos educativos.
#
# **Valor de las notas de débito:**
#
# Los valores de las notas de débito tienen un promedio de 777.171, pero lo interesante es que la mediana es bastante menor (537.500), lo que nos indica que hay algunos créditos con valores muy altos que están elevando el promedio. La mayoría de los créditos se concentra en montos más moderados, con el 50% de ellos entre 307.798 y 903.200. Sin embargo, encontramos casos extremos que llegan hasta los $85.5 millones, lo que sugiere una gran diversidad en los tipos de créditos otorgados.
#
# **Pagos realizados:**
#
# En cuanto a los pagos, vemos un comportamiento similar. El promedio de lo pagado por nota de débito es de 726.923, con una mediana de 510.000. Esto significa que, en general, los estudiantes han estado pagando sus obligaciones, aunque la variabilidad es alta. Lo más notable es que hay notas de débito completamente pagadas (valores que llegan al máximo de 85.5 millones) y otras que aún no han recibido ningún pago (mínimo de 0).
#
# **Saldo pendiente:**
#
# El saldo promedio pendiente es relativamente bajo (50.248), pero aquí hay algo importante: la mediana es 0, lo que significa que más de la mitad de las notas de débito están completamente pagadas. Esto es una señal positiva de recuperación. Sin embargo, hay casos con saldos muy altos (hasta 42 millones), lo que representa un riesgo de cartera que debe monitorearse.
#
# **Porcentaje de recaudo:**
#
# Esta es quizás la métrica más alentadora: el porcentaje promedio de recaudo es del 96%, y la mediana es del 100%. Esto nos dice que la gran mayoría de los créditos educativos están siendo pagados en su totalidad. De hecho, el 75% de los casos tienen un recaudo del 100%, lo que refleja una buena cultura de pago entre los beneficiarios.
#
# **Cantidad de cuotas:**
#
# Los créditos tienen en promedio 8 cuotas, aunque la mediana es de solo 4, lo que indica que muchos créditos son a corto plazo. La mayoría se paga entre 1 y 5 cuotas, aunque hay casos que se extienden hasta 208 cuotas (más de 17 años), probablemente para créditos de mayor monto.

# %%
# Variables numéricas reales (Cartera Depurada)
num_cartera_reales = [
    "SALDO",
    "CUOTA",
    "VALOR BRUTO",
    "VALOR DESCUENTO",
    "VALOR TOTAL",
    "VALOR AFECTADO",
    "VALOR DOCUMENTO",
    "TASA INTERÉS MORA",
    "EDAD CARTERA",
    "DÍAS",
    "MESES DIFERIDO"
]

# Filtrar columnas existentes
num_cartera_reales = [col for col in num_cartera_reales if col in cartera_df.columns]

# Estadísticas descriptivas
desc_cartera = cartera_df[num_cartera_reales].describe().T

# Mediana y rango
desc_cartera["median"] = cartera_df[num_cartera_reales].median()
desc_cartera["range"] = desc_cartera["max"] - desc_cartera["min"]

# Ordenar columnas
desc_cartera = desc_cartera[
    ["count", "mean", "median", "std", "min", "25%", "50%", "75%", "max", "range"]
]

# Convertir TODAS las columnas a numéricas (para aplicar formato sin decimales)
for col in desc_cartera.columns:
    desc_cartera[col] = pd.to_numeric(desc_cartera[col], errors="coerce")

# Mostrar tabla con estilo premium y sin decimales
estilo_tabla(desc_cartera, "📊 Estadísticas Descriptivas – Cartera Depurada")
# Out:
# <style type="text/css">
# #T_ea3d7 caption {
#   color: #2c3e50;
#   font-size: 16px;
#   font-weight: bold;
#   text-align: left;
#   margin-bottom: 10px;
# }
# #T_ea3d7 th {
#   background-color: #2c3e50;
#   color: white;
#   font-weight: bold;
#   border: 1px solid #ddd;
#   padding: 5px;
# }
# #T_ea3d7 td {
#   border: 1px solid #ddd;
#   padding: 5px;
# }
# #T_ea3d7_row0_col0, #T_ea3d7_row0_col1, #T_ea3d7_row0_col2, #T_ea3d7_row0_col3, #T_ea3d7_row0_col4, #T_ea3d7_row0_col5, #T_ea3d7_row0_col6, #T_ea3d7_row0_col7, #T_ea3d7_row0_col8, #T_ea3d7_row0_col9, #T_ea3d7_row1_col0, #T_ea3d7_row1_col1, #T_ea3d7_row1_col2, #T_ea3d7_row1_col3, #T_ea3d7_row1_col4, #T_ea3d7_row1_col5, #T_ea3d7_row1_col6, #T_ea3d7_row1_col7, #T_ea3d7_row1_col8, #T_ea3d7_row1_col9, #T_ea3d7_row2_col0, #T_ea3d7_row2_col1, #T_ea3d7_row2_col2, #T_ea3d7_row2_col3, #T_ea3d7_row2_col4, #T_ea3d7_row2_col5, #T_ea3d7_row2_col6, #T_ea3d7_row2_col7, #T_ea3d7_row2_col8, #T_ea3d7_row2_col9, #T_ea3d7_row3_col0, #T_ea3d7_row3_col1, #T_ea3d7_row3_col2, #T_ea3d7_row3_col3, #T_ea3d7_row3_col4, #T_ea3d7_row3_col5, #T_ea3d7_row3_col6, #T_ea3d7_row3_col7, #T_ea3d7_row3_col8, #T_ea3d7_row3_col9, #T_ea3d7_row4_col0, #T_ea3d7_row4_col1, #T_ea3d7_row4_col2, #T_ea3d7_row4_col3, #T_ea3d7_row4_col4, #T_ea3d7_row4_col5, #T_ea3d7_row4_col6, #T_ea3d7_row4_col7, #T_ea3d7_row4_col8, #T_ea3d7_row4_col9, #T_ea3d7_row5_col0, #T_ea3d7_row5_col1, #T_ea3d7_row5_col2, #T_ea3d7_row5_col3, #T_ea3d7_row5_col4, #T_ea3d7_row5_col5, #T_ea3d7_row5_col6, #T_ea3d7_row5_col7, #T_ea3d7_row5_col8, #T_ea3d7_row5_col9, #T_ea3d7_row6_col0, #T_ea3d7_row6_col1, #T_ea3d7_row6_col2, #T_ea3d7_row6_col3, #T_ea3d7_row6_col4, #T_ea3d7_row6_col5, #T_ea3d7_row6_col6, #T_ea3d7_row6_col7, #T_ea3d7_row6_col8, #T_ea3d7_row6_col9, #T_ea3d7_row7_col0, #T_ea3d7_row7_col1, #T_ea3d7_row7_col2, #T_ea3d7_row7_col3, #T_ea3d7_row7_col4, #T_ea3d7_row7_col5, #T_ea3d7_row7_col6, #T_ea3d7_row7_col7, #T_ea3d7_row7_col8, #T_ea3d7_row7_col9, #T_ea3d7_row8_col0, #T_ea3d7_row8_col1, #T_ea3d7_row8_col2, #T_ea3d7_row8_col3, #T_ea3d7_row8_col4, #T_ea3d7_row8_col5, #T_ea3d7_row8_col6, #T_ea3d7_row8_col7, #T_ea3d7_row8_col8, #T_ea3d7_row8_col9, #T_ea3d7_row9_col0, #T_ea3d7_row9_col1, #T_ea3d7_row9_col2, #T_ea3d7_row9_col3, #T_ea3d7_row9_col4, #T_ea3d7_row9_col5, #T_ea3d7_row9_col6, #T_ea3d7_row9_col7, #T_ea3d7_row9_col8, #T_ea3d7_row9_col9, #T_ea3d7_row10_col0, #T_ea3d7_row10_col1, #T_ea3d7_row10_col2, #T_ea3d7_row10_col3, #T_ea3d7_row10_col4, #T_ea3d7_row10_col5, #T_ea3d7_row10_col6, #T_ea3d7_row10_col7, #T_ea3d7_row10_col8, #T_ea3d7_row10_col9 {
#   text-align: left;
# }
# </style>
# <table id="T_ea3d7" class="dataframe">
#   <caption>📊 Estadísticas Descriptivas – Cartera Depurada</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ea3d7_level0_col0" class="col_heading level0 col0" >count</th>
#       <th id="T_ea3d7_level0_col1" class="col_heading level0 col1" >mean</th>
#       <th id="T_ea3d7_level0_col2" class="col_heading level0 col2" >median</th>
#       <th id="T_ea3d7_level0_col3" class="col_heading level0 col3" >std</th>
#       <th id="T_ea3d7_level0_col4" class="col_heading level0 col4" >min</th>
#       <th id="T_ea3d7_level0_col5" class="col_heading level0 col5" >25%</th>
#       <th id="T_ea3d7_level0_col6" class="col_heading level0 col6" >50%</th>
#       <th id="T_ea3d7_level0_col7" class="col_heading level0 col7" >75%</th>
#       <th id="T_ea3d7_level0_col8" class="col_heading level0 col8" >max</th>
#       <th id="T_ea3d7_level0_col9" class="col_heading level0 col9" >range</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ea3d7_level0_row0" class="row_heading level0 row0" >SALDO</th>
#       <td id="T_ea3d7_row0_col0" class="data row0 col0" >27,330</td>
#       <td id="T_ea3d7_row0_col1" class="data row0 col1" >829,633</td>
#       <td id="T_ea3d7_row0_col2" class="data row0 col2" >342,985</td>
#       <td id="T_ea3d7_row0_col3" class="data row0 col3" >1,720,974</td>
#       <td id="T_ea3d7_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_ea3d7_row0_col5" class="data row0 col5" >97,538</td>
#       <td id="T_ea3d7_row0_col6" class="data row0 col6" >342,985</td>
#       <td id="T_ea3d7_row0_col7" class="data row0 col7" >876,600</td>
#       <td id="T_ea3d7_row0_col8" class="data row0 col8" >77,520,000</td>
#       <td id="T_ea3d7_row0_col9" class="data row0 col9" >77,520,000</td>
#     </tr>
#     <tr>
#       <th id="T_ea3d7_level0_row1" class="row_heading level0 row1" >CUOTA</th>
#       <td id="T_ea3d7_row1_col0" class="data row1 col0" >20,835</td>
#       <td id="T_ea3d7_row1_col1" class="data row1 col1" >19</td>
#       <td id="T_ea3d7_row1_col2" class="data row1 col2" >5</td>
#       <td id="T_ea3d7_row1_col3" class="data row1 col3" >24</td>
#       <td id="T_ea3d7_row1_col4" class="data row1 col4" >0</td>
#       <td id="T_ea3d7_row1_col5" class="data row1 col5" >3</td>
#       <td id="T_ea3d7_row1_col6" class="data row1 col6" >5</td>
#       <td id="T_ea3d7_row1_col7" class="data row1 col7" >30</td>
#       <td id="T_ea3d7_row1_col8" class="data row1 col8" >208</td>
#       <td id="T_ea3d7_row1_col9" class="data row1 col9" >208</td>
#     </tr>
#     <tr>
#       <th id="T_ea3d7_level0_row2" class="row_heading level0 row2" >VALOR BRUTO</th>
#       <td id="T_ea3d7_row2_col0" class="data row2 col0" >27,330</td>
#       <td id="T_ea3d7_row2_col1" class="data row2 col1" >948,307</td>
#       <td id="T_ea3d7_row2_col2" class="data row2 col2" >446,044</td>
#       <td id="T_ea3d7_row2_col3" class="data row2 col3" >2,534,522</td>
#       <td id="T_ea3d7_row2_col4" class="data row2 col4" >0</td>
#       <td id="T_ea3d7_row2_col5" class="data row2 col5" >141,480</td>
#       <td id="T_ea3d7_row2_col6" class="data row2 col6" >446,044</td>
#       <td id="T_ea3d7_row2_col7" class="data row2 col7" >922,997</td>
#       <td id="T_ea3d7_row2_col8" class="data row2 col8" >273,709,934</td>
#       <td id="T_ea3d7_row2_col9" class="data row2 col9" >273,709,934</td>
#     </tr>
#     <tr>
#       <th id="T_ea3d7_level0_row3" class="row_heading level0 row3" >VALOR DESCUENTO</th>
#       <td id="T_ea3d7_row3_col0" class="data row3 col0" >27,330</td>
#       <td id="T_ea3d7_row3_col1" class="data row3 col1" >0</td>
#       <td id="T_ea3d7_row3_col2" class="data row3 col2" >0</td>
#       <td id="T_ea3d7_row3_col3" class="data row3 col3" >0</td>
#       <td id="T_ea3d7_row3_col4" class="data row3 col4" >0</td>
#       <td id="T_ea3d7_row3_col5" class="data row3 col5" >0</td>
#       <td id="T_ea3d7_row3_col6" class="data row3 col6" >0</td>
#       <td id="T_ea3d7_row3_col7" class="data row3 col7" >0</td>
#       <td id="T_ea3d7_row3_col8" class="data row3 col8" >0</td>
#       <td id="T_ea3d7_row3_col9" class="data row3 col9" >0</td>
#     </tr>
#     <tr>
#       <th id="T_ea3d7_level0_row4" class="row_heading level0 row4" >VALOR TOTAL</th>
#       <td id="T_ea3d7_row4_col0" class="data row4 col0" >27,330</td>
#       <td id="T_ea3d7_row4_col1" class="data row4 col1" >948,307</td>
#       <td id="T_ea3d7_row4_col2" class="data row4 col2" >446,044</td>
#       <td id="T_ea3d7_row4_col3" class="data row4 col3" >2,534,522</td>
#       <td id="T_ea3d7_row4_col4" class="data row4 col4" >0</td>
#       <td id="T_ea3d7_row4_col5" class="data row4 col5" >141,480</td>
#       <td id="T_ea3d7_row4_col6" class="data row4 col6" >446,044</td>
#       <td id="T_ea3d7_row4_col7" class="data row4 col7" >922,997</td>
#       <td id="T_ea3d7_row4_col8" class="data row4 col8" >273,709,934</td>
#       <td id="T_ea3d7_row4_col9" class="data row4 col9" >273,709,934</td>
#     </tr>
#     <tr>
#       <th id="T_ea3d7_level0_row5" class="row_heading level0 row5" >VALOR AFECTADO</th>
#       <td id="T_ea3d7_row5_col0" class="data row5 col0" >27,330</td>
#       <td id="T_ea3d7_row5_col1" class="data row5 col1" >137,400</td>
#       <td id="T_ea3d7_row5_col2" class="data row5 col2" >0</td>
#       <td id="T_ea3d7_row5_col3" class="data row5 col3" >1,626,035</td>
#       <td id="T_ea3d7_row5_col4" class="data row5 col4" >0</td>
#       <td id="T_ea3d7_row5_col5" class="data row5 col5" >0</td>
#       <td id="T_ea3d7_row5_col6" cla

# %% [markdown]
# **Análisis de Estadísticas Descriptivas - Dataset Cartera Depurada**
#
#
# El análisis de la cartera depurada nos ofrece una visión más detallada del estado actual de los créditos y su comportamiento de pago.
#
# **Saldo de la cartera:**
#
# El saldo promedio por registro es de 829.633, con una mediana de 342.985, lo que nuevamente indica que hay algunos créditos con saldos muy elevados que jalan el promedio hacia arriba. La mitad de los registros tiene saldos entre 97.538 y 876.600. Los casos extremos llegan hasta 77.5 millones, lo que representa los créditos más grandes y posiblemente más antiguos en la cartera.
#
# **Valor de las cuotas:**
#
# Las cuotas tienen un promedio de 19, pero aquí hay algo curioso: la mediana es de solo 5, lo que sugiere que muchos créditos tienen cuotas pequeñas o están prácticamente liquidados. El rango es amplio, desde 0 hasta 208, reflejando la diversidad en los esquemas de pago.
#
# **Montos totales:**
#
# El valor bruto promedio de los créditos es de 948,307, prácticamente igual al valor total (948.307) y al valor del documento (948.307), lo que tiene sentido porque estos tres campos deberían ser similares. La mediana está alrededor de 446.044, indicando que la mitad de los créditos son de montos moderados, mientras que los más grandes alcanzan los 273 millones.
#
# **Descuentos e intereses de mora:**
#
# Algo muy llamativo es que tanto el valor de descuento como la tasa de interés de mora tienen valores de cero en todas sus estadísticas (media, mediana, percentiles). Esto significa que estas columnas probablemente están vacías o no se están aplicando descuentos ni cobrando intereses moratorios en esta cartera, lo cual es inusual y debería verificarse.
#
# **Valor afectado:**
#
# El valor afectado promedio es de 137.400, pero la mediana es 0, lo que indica que más de la mitad de los créditos no tienen montos afectados (posiblemente por mora o problemas). Sin embargo, hay casos donde el valor afectado llega hasta 224 millones, lo que representa créditos con serios problemas de recuperación.
#
# **Edad de la cartera:**
#
# La cartera tiene en promedio 9 años de antigüedad, con una mediana también de 9 años. Esto indica que estamos trabajando con créditos relativamente antiguos. El 75% de la cartera tiene entre 7 y 13 años, y el crédito más antiguo tiene 14 años. Esta antigüedad puede estar relacionada con la dificultad de recuperación en algunos casos.
#
#
# **Días de atraso o anticipación:**
#
# Aquí encontramos algo que requiere atención: el promedio de días es 450, pero hay valores negativos (mínimo de -4,773 días), lo que podría indicar pagos anticipados o errores en el cálculo de fechas. La mediana es de -5 días, sugiriendo que muchos pagos se realizan antes de la fecha de vencimiento. Sin embargo, hay casos con atrasos de hasta 9,021 días (casi 25 años), lo cual es extremo y debe investigarse.
#
# **Meses diferidos:**
#
# Los créditos tienen en promedio 1 mes diferido, con una mediana de 0 meses, indicando que la mayoría no tiene períodos de gracia. El rango va de 0 a 10 meses, lo que muestra flexibilidad en algunos casos especiales.

# %% [markdown]
# **Conclusión General:**
#
# Ambos datasets muestran una cartera de créditos educativos con un comportamiento mayormente positivo en términos de recaudo, pero con algunos casos extremos que requieren atención especial. La antigüedad de la cartera y la presencia de valores atípicos en días y montos afectados sugieren que hay un segmento de créditos problemáticos que deberían ser el foco de las estrategias de cobranza y gestión de riesgo.

# %% [markdown]
# **Análisis de Variables Categóricas (Estadísticas de Frecuencia)**

# %%
def resumen_categoricas(df, titulo="Resumen de Variables Categóricas"):
    cat_cols = df.select_dtypes(include=["category", "object", "string"]).columns

    tablas = {}
    for col in cat_cols:
        tablas[col] = (
            df[col]
            .value_counts(dropna=False)
            .to_frame("count")
            .assign(percentage=lambda x: (x["count"] / x["count"].sum() * 100).round(2))
        )

    print(f"🔎 {titulo}: {len(cat_cols)} variables encontradas")
    return tablas

tablas_creditos = resumen_categoricas(creditos_df, "Créditos – Variables Categóricas")
tablas_cartera  = resumen_categoricas(cartera_df, "Cartera Depurada – Variables Categóricas")
# Out:
# 🔎 Créditos – Variables Categóricas: 14 variables encontradas
# 🔎 Cartera Depurada – Variables Categóricas: 29 variables encontradas

# %% [markdown]
# Función para generar tablas con estilo:

# %%
def tabla_frecuencias(df, col, titulo=None):
    """
    Genera una tabla con:
    - Conteos
    - Porcentajes
    Visualizada con estilo_tabla()
    """
    tabla = (
        df[col]
        .value_counts(dropna=False)
        .to_frame("count")
        .assign(percentage=lambda x: (x["count"] / x["count"].sum() * 100).round(2))
    )

    return estilo_tabla(tabla, titulo if titulo else f"Frecuencias de {col}")

# %% [markdown]
# Identificar variables categóricas por dataset:

# %%
# Variables categóricas en Créditos
cat_creditos = creditos_df.select_dtypes(include=["category", "object", "string"]).columns.tolist()

# Variables categóricas en Cartera Depurada
cat_cartera = cartera_df.select_dtypes(include=["category", "object", "string"]).columns.tolist()

print("CATEGÓRICAS – Créditos:", len(cat_creditos))
print("CATEGÓRICAS – Cartera Depurada:", len(cat_cartera))
# Out:
# CATEGÓRICAS – Créditos: 14
# CATEGÓRICAS – Cartera Depurada: 29
